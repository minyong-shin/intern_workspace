# %%
import os
import sys
import pandas as pd
import requests
import re
from datetime import datetime
from bs4 import BeautifulSoup
from selenium.webdriver import Chrome
from selenium.webdriver.common.keys import Keys
import time

# %%
browser = Chrome()
delay = 3
base_url = 'https://cafe.naver.com/anakorea'

# %%
browser.get(base_url)
browser.implicitly_wait(delay)

# %%
browser.find_element_by_css_selector('span.gnb_txt').click()
browser.implicitly_wait(delay)

# %% [markdown]
# ## 네이버 로그인 보안 강화로 코드로 접속 불가, 직접 쳐야한다.
# #### browser.find_element_by_name('id').send_keys(naver_id)
# #### browser.find_element_by_name('pw').send_keys(naver_pw)
# #### browser.find_element_by_css_selector('input.btn_global').send_keys(Keys.ENTER)

# %%
cafe_menu = browser.find_element_by_css_selector('div#cafe-menu')
browser.implicitly_wait(delay)

# %%
menu_list = cafe_menu.find_elements_by_tag_name('a')

# %%
menu_source = pd.DataFrame({'name' : [], 'source' : []})
name = []
source = []

for menu in menu_list :
    menu_name = menu.text
    if '전체글' in menu_name : # 원하는 검색어를 집어넣어야 한다.
        insert_menu = pd.DataFrame({'name' : [menu_name], 'source' : [menu]})
        menu_source = menu_source.append(insert_menu)

# %%
menu_source.index = range(len(menu_source))

# %%
menu_source
# Out:
#     name                                             source
# 0  전체글보기  <selenium.webdriver.remote.webelement.WebEleme...

# %%
# 원하는 카테고리 클릭을 위해서 인덱싱을 진행하는데, 앞에부분만 바꾸면된다.
menu_source.iloc[0,1].send_keys(Keys.ENTER)
                                            
browser.implicitly_wait(delay)

# %%
i = 1
post_list = pd.DataFrame({'name' : [],
                         'user' : [],
                         'time' : [],
                         'link' : []})
while True :
    try :
        browser.switch_to_frame(browser.find_element_by_name('cafe_main'))
        page = browser.find_element_by_css_selector('div.prev-next')
        page_num = page.find_elements_by_tag_name('a')
    except :
        page = browser.find_element_by_css_selector('div.prev-next')
        page_num = page.find_elements_by_tag_name('a')        
    
    for num in range(len(page_num)) :           
            try :  
                browser.switch_to_frame(browser.find_element_by_name('cafe_main'))
                page = browser.find_element_by_css_selector('div.prev-next')
                page_num = page.find_elements_by_tag_name('a')
                if '다음' in page_num[num].text :
                    page_num[num].send_keys(Keys.ENTER)
                    break
                elif '이전' in page_num[num].text :
                    pass
                else :
                    page_num[num].send_keys(Keys.ENTER)
            except :
                page = browser.find_element_by_css_selector('div.prev-next')
                page_num = page.find_elements_by_tag_name('a')
                if '다음' in page_num[num].text :
                    page_num[num].send_keys(Keys.ENTER)
                    break        
                elif '이전' in page_num[num].text :
                    pass
                else :
                    page_num[num].send_keys(Keys.ENTER)
                
            source = browser.page_source
            html = BeautifulSoup(source, 'html.parser')
            tbody = html.find('div', {'class' : 'article-board m-tcol-c'})
            post_name = tbody.find_all('span', {'class' :'aaa'})
            post_user = tbody.find_all('span', {'class' : 'wordbreak'})
            post_time = tbody.find_all('td', {'class' : 'view-count m-tcol-c'})

            name = []
            user = []
            time = []
            link = []

            for n in post_name :
                name.append(n.text.replace('\n',''))
                
            for u in post_user :
                user.append(u.text)

            for t in range(0,len(post_time),3) :
                time.append(re.sub('[^0-9\.\:]', '', post_time[t].text))
                
            for l in post_name :
                post_link = base_url + l.find('a')['href']
                link.append(post_link)

            posting = pd.DataFrame({'name' : name,
                                    'user' : user,
                                    'time' : time,
                                    'link' : link})

            post_list = post_list.append(posting)

    if len(page_num) < 11 :
        break
    
post_list = post_list.drop_duplicates(subset='name', keep='last')
post_list.index = range(len(post_list))
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: DeprecationWarning: use driver.switch_to.frame instead

# %%
post_list
# Out:
#                                                    name         user  \
# 0                               PRADA 6007 남성 파우치 가방입니다          무소유
# 1                                 ARMANI 2019 남성 운동화입니다          무소유
# 2                                 BALENCIAGA 여성 장목양말입니다          무소유
# 3                     아동복땡처리 재고 대량 소량  매입합니다 ~~초고가매입합니다     kaka0371
# 4                               CARTIER 2019 남성 손목시계입니다          무소유
# 5                              GUCCI 1888 남성 양모 라운드티입니다          무소유
# 6          거 있잖은가 ? 010  2239  5627  도깨비 이두표 각종재고 매입합니다       도깨비이두표
# 7                                  홈쇼핑 히트! 봄 블라우스+플레어팬츠     BijouAnn
# 8                                 라쿤퍼 오리털 패딩 시즌오프 최종 정리     BijouAnn
# 9                              시즌오프 여성 브랜드 기모팬츠 최종 처분해요     BijouAnn
# 10                                  PRADA 2019 남성 가방입니다          무소유
# 11                               APE 2019  브이 슬림 원피스입니다          무소유
# 12                           CHOPARD 101301 남성 스포츠시계입니다          무소유
# 13                                      ARMANI 남성 니트입니다          무소유
# 14                    BURBERRY OY1901122 남성 카라 반팔티입니다            무소유
# 15                                 NIKE 967678 남성 바지입니다          무소유
# 16                               POLO 1006 남성 카라 반팔티입니다          무소유
# 17                                  KENZO 1816 남성 남방입니다          무소유
# 18                                  HAZZYS 남성 카라 반팔티입니다          무소유
# 19        사장님 여기 유통과정이나 확실히 받을수 있는지 여부가 명시되어있움 좋을거 같아요~      123dd11
# 20                            GUCCI 103682 남성 운동화입니다[2]          무소유
# 21                          BALENCIAGA 777-77 여성 운동화입니다          무소유
# 22                         CHRISTIAN DIOR 3399 여성 가방입니다          무소유
# 23                                 ARMANI 1801 남성 남방입니다          무소유
# 24                          COOFANDY TETE-SIX 남성 카라티입니다          무소유
# 25                                      남성 후두 반팔티 덤핑입니다          무소유
# 26                                코로나이즈 가지고 계신분 구합니다[1]         노멀GS
# 27                            CALLAWAY 남성  라운드 골프티입니다            무소유
# 28                                VERSACE 2362 여성 가방입니다          무소유
# 29                  NIKE AIR MAX 270 FLy KNIT 남성 운동화입니다          무소유
# ...                                                 ...          ...
# 7049                    다양한 봄 쟈켓과 코트 출시.....일산 풍동 네오샵^^          네오샵
# 7050                                  의류도매...네오에스아이입니다.          네오샵
# 7051                  봄신상품아줌마옷 공장티스토리 가격 품질 최강 바로 문의하세요   매일 새롭게 새롭게
# 7064  2014.12.12.  https://cafe.naver.com/anakorea/ArticleRead.nh...
# 7065  2014.12.11.  https://cafe.naver.com/anakorea/ArticleRead.nh...
# 7066  2014.12.09.  https://cafe.naver.com/anakorea/ArticleRead.nh...
# 7067  2014.12.09.  https://cafe.naver.com/anakorea/ArticleRead.nh...
# 7068  2014.12.09.  https://cafe.naver.com/anakorea/ArticleRead.nh...
# 7069  2014.12.02.  https://cafe.naver.com/anakorea/ArticleRead.nh...
# 7070  2014.11.28.  https://cafe.naver.com/anakorea/ArticleRead.nh...
# 7071  2014.11.21.  https://cafe.naver.com/anakorea/ArticleRead.nh...
# 7072  2014.11.11.  https://cafe.naver.com/anakorea/ArticleRead.nh...
# 7073  2014.11.07.  https://cafe.naver.com/anakorea/ArticleRead.nh...
# 7074  2014.11.07.  https://cafe.naver.com/anakorea/ArticleRead.nh...
# 7075  2014.10.14.  https://cafe.naver.com/anakorea/ArticleRead.nh...
# 7076  2014.10.08.  https://cafe.naver.com/anakorea/ArticleRead.nh...
# 7077  2014.10.03.  https://cafe.naver.com/anakorea/ArticleRead.nh...
# 7078  2014.09.26.  https://cafe.naver.com/anakorea/ArticleRead.nh...
#
# [7079 rows x 4 columns]

# %%
post_list.to_csv(os.getcwd() + "/" + "cafe_anakorea" + ".csv", mode = 'w', header = True, index = None, encoding = 'utf-8-sig')

# %%
post_list['user'].value_counts()
# Out:
# 덤핑 의류           3299
# 무소유             2501
# BM               303
# 비쥬앤              198
# BM의류             131
# kaka0371          74
# BijouAnn          69
# bunnykennel       49
# 도깨비이두표            46
# 넥스트상사1            45
# 네오샵               43
# 아동복쪼아             39
# 매일 새롭게 새롭게        28
# 소록유통              17
# 오리진시스템최석재         14
# 블루웰               12
# 동대문               10
# power72920        10
# 현스탁유통              9
# 세꼬마                9
# 니트도매               9
# boss               8
# 폐업처분               7
# 도매SY컴퍼니            7
# 오리오리9              6
# 미니베이직              6
# 원도매SY컴퍼니           5
# treenick9664       5
# 공인                 5
# 돈마니                5
#                 ...
# 1520               1
# NPUTAY             1
# 하트궁딩이              1
# 유한업체               1
# 넥스트무역              1
# solid0440          1
# 헬스마일               1
# 가격택만구입             1
# 마나맨                1
# 짱아야                1
# 의류땡처리              1
# SY코퍼레이션            1
# god                1
# 마스터맨2              1
# 투엔티식스              1
# 블리블리               1
# 꿀꿀이                1
# 홍마니                1
# oenalla            1
# 쿨맥스                1
# csj7396            1
# 에룽이                1
# 노멀GS               1
# METALLICA          1
# 선수                 1
# 똥글뱅이               1
# 예티                 1
# 곰댕댕이               1
# 옹옹                 1
# july3873           1
# Name: user, Length: 103, dtype: int64

# %%
post_list['user'].value_counts().to_csv(os.getcwd() + "/" + "cafe_anakorea_userlist" + ".csv", mode = 'w', header = True, encoding = 'utf-8-sig')

# %%
import sys
sys.stdin.encoding
# Out:
# 'cp949'

# %%
sys.stdout.encoding
# Out:
# 'UTF-8'
