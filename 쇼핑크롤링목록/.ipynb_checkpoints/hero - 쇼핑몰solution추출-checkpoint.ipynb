# %%
import requests # 웹 페이지 소스를 얻기 위한 패키지(기본 내장 패키지이다.)
from bs4 import BeautifulSoup # 웹 페이지 소스를 얻기 위한 패키지, 더 간단히 얻을 수 있다는 장점이 있다고 한다.
from datetime import datetime                                # (!pip install beautifulsoup4 으로 다운받을 수 있다.)
import pandas as pd # 데이터를 처리하기 위한 가장 기본적인 패키지
import time # 사이트를 불러올 때, 작업 지연시간을 지정해주기 위한 패키지이다. (사이트가 늦게 켜지면 에러가 발생하기 때문)
import urllib.request #
from selenium.webdriver import Chrome
import json
import re

# %%
#oserror 해결법 = Initializing from file failed 
#비어있는 행은 자연스럽게 삭제됨
shop = pd.read_csv('쇼핑몰목록.csv',engine = 'python')

# %%
shop['쇼핑몰URL'].iloc[0]
# Out:
# 'http://www.66girls.co.kr/'

# %%
base_url = "http://www.66girls.co.kr/"

# %%
req = requests.get(base_url)
if req == 200 :
    soup = BeautifulSoup(req.content, 'html.parser')
else :
    req = requests.get(base_url, headers = {'user-agent': ('Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko)'
                                                                            'Chrome/71.0.3578.98 Safari/537.36')})
    soup = BeautifulSoup(req.content, 'html.parser')

# %%
req
# Out:
# <Response [200]>

# %%
soup.find()

# %%
page_source = req.text

# %%
re.search(r'cafe24',page_source)
# Out:
# <_sre.SRE_Match object; span=(3751, 3757), match='cafe24'>

# %%
match = re.search(r'var EC_ROOT_DOMAIN = (.+);',page_source)

# %%
match
# Out:
# <_sre.SRE_Match object; span=(3996, 4030), match='var EC_ROOT_DOMAIN = "cafe24.com";'>

# %%
'cafe' in str(match)
# Out:
# True

# %%
'naver' in shop['쇼핑몰URL'].iloc[915]
# Out:
# True

# %%
shop['쇼핑몰URL'].iloc[6]
# Out:
# 'http://www.mocobling.com/'

# %%
#네이버 쇼핑몰 예외처리해야함
shop_solution = pd.DataFrame({'url':[],
                             'solution':[]})
for i in range(len(shop)):
    try:
        if 'naver' in shop['쇼핑몰URL'].iloc[i]:
            url = shop['쇼핑몰URL'].iloc[i]
            solution = 'naver'
            insert_data = pd.DataFrame({'url':[url],
                                        'solution':[solution]})
        else:
            url = shop['쇼핑몰URL'].iloc[i]
            req = requests.get(url)
            if req == 200 :
                soup = BeautifulSoup(req.content, 'html.parser')
            else :
                req = requests.get(url, headers = {'user-agent': ('Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko)'
                                                                                        'Chrome/71.0.3578.98 Safari/537.36')})
                soup = BeautifulSoup(req.content, 'html.parser')
            page_source = req.text
            match = re.search(r'cafe24',page_source)
                #match = re.search(r'var EC_ROOT_DOMAIN = (.+);',page_source)#보류

            if match:
                solution = 'cafe24'
            else:
                match = re.search(r'makeshop',page_source)
                if match:
                    solution = 'makeshop'
                else:
                    match = re.search(r'godohosting',page_source)
                    if match:
                        solution = 'godomall'
                    else:
                        solution = 'another solution'
                    
            insert_data = pd.DataFrame({'url':[url],
                            'solution':[solution]})
            
        shop_solution = shop_solution.append(insert_data) 
    except:
         #아예 접속이 안되는 url -> 이것도 예외처리로 봅아내면 될 듯
        url = shop['쇼핑몰URL'].iloc[i]
        solution = 'request x'
        insert_data = pd.DataFrame({'url':[url],
                            'solution':[solution]})
        shop_solution = shop_solution.append(insert_data) 
shop_solution.index = range(len(shop_solution))
# Out:
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.

# %%
shop_solution
# Out:
#                                                    url          solution
# 0                            http://www.66girls.co.kr/            cafe24
# 1                                http://www.imvely.com            cafe24
# 2                              http://www.naning9.com/  another solution
# 3                            http://www.stylenanda.com            cafe24
# 4                             http://www.hotping.co.kr            cafe24
# 5                             http://www.sonyunara.com  another solution
# 6                            http://www.mocobling.com/          makeshop
# 7                                http://www.ggsing.com            cafe24
# 8                               http://www.thedaze.kr/            cafe24
# 9                           http://www.loveloveme.com/            cafe24
# 10                               http://www.angtoo.com            cafe24
# 11                       http://www.littleblack.co.kr/            cafe24
# 12                               http://www.11am.co.kr            cafe24
# 13                           http://www.michyeora.com/            cafe24
# 14                          http://www.miamasvin.co.kr            cafe24
# 15                          http://www.merongshop.com/            cafe24
# 2    http://www.naning9.com/   서울시 종로구
# 3  http://www.stylenanda.com   서울시 마포구
# 4   http://www.hotping.co.kr  부산시 해운대구

# %%
shop = shop[['쇼핑몰URL']]

# %%
#네이버 쇼핑몰 예외처리해야함
shop_solution = pd.DataFrame({'url':[],
                             'solution':[]})
for i in range(len(shop)):
    try:
        if 'naver' in shop['쇼핑몰URL'].iloc[i]:
            url = shop['쇼핑몰URL'].iloc[i]
            solution = 'naver'
            insert_data = pd.DataFrame({'url':[url],
                                        'solution':[solution]})
        else:
            url = shop['쇼핑몰URL'].iloc[i]
            req = requests.get(url)
            if req == 200 :
                soup = BeautifulSoup(req.content, 'html.parser')
            else :
                req = requests.get(url, headers = {'user-agent': ('Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko)'
                                                                                        'Chrome/71.0.3578.98 Safari/537.36')})
                soup = BeautifulSoup(req.content, 'html.parser')
            page_source = req.text
            match = re.search(r'cafe24',page_source)
            #match = re.search(r'var EC_ROOT_DOMAIN = (.+);',page_source)#보류
            #정규표현식을 이용해서 찾지 않고 request로 단순 text화 시킨 것을 'cafe24' in pagesource로
            #찾는다. 이때 조건문을 사용하여 if 'cafe24' in pagesource & 'makeshop' in pagesource부터
            if match:
                solution = 'cafe24'
            else:
                match = re.search(r'makeshop',page_source)
                if match:
                    solution = 'makeshop'
                else:
                    match = re.search(r'godohosting',page_source)
                    if match:
                        solution = 'godomall'
                    else:
                        solution = 'another solution'
                    
            insert_data = pd.DataFrame({'url':[url],
                            'solution':[solution]})
            
        shop_solution = shop_solution.append(insert_data) 
    except:
         #아예 접속이 안되는 url -> 이것도 예외처리로 봅아내면 될 듯
        url = shop['쇼핑몰URL'].iloc[i]
        solution = 'request x'
        insert_data = pd.DataFrame({'url':[url],
                            'solution':[solution]})
        shop_solution = shop_solution.append(insert_data) 
shop_solution.index = range(len(shop_solution))
# Out:
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.

# %% [markdown]
# # 여성 쇼핑몰 운영솔루션 v2.0

# %%
shop_solution = pd.DataFrame({'url':[],
                             'solution':[]})
for i in range(len(shop)):
    try:
        if 'naver' in shop['쇼핑몰URL'].iloc[i]:
            url = shop['쇼핑몰URL'].iloc[i]
            solution = 'naver'
            insert_data = pd.DataFrame({'url':[url],
                                        'solution':[solution]})
        else:
            url = shop['쇼핑몰URL'].iloc[i]
            req = requests.get(url)
            if req == 200 :
                soup = BeautifulSoup(req.content, 'html.parser')
            else :
                req = requests.get(url, headers = {'user-agent': ('Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko)'
                                                                                        'Chrome/71.0.3578.98 Safari/537.36')})
                soup = BeautifulSoup(req.content, 'html.parser')
            page_source = req.text
            
            if 'makeshop' in page_source.lower() and 'cafe24' in page_source.lower():
                solution = "c/m both"
            elif 'cafe24' in page_source.lower():
                solution = "cafe24"
            elif 'makeshop' in page_source.lower():
                solution = "makeshop"
            elif 'godohosting' in page_source.lower():
                solution = "godomall"
            else:
                solution = "another solution"
                
            insert_data = pd.DataFrame({'url':[url],
                            'solution':[solution]})
            
        shop_solution = shop_solution.append(insert_data) 
    except:
         #아예 접속이 안되는 url -> 이것도 예외처리로 봅아내면 될 듯
        url = shop['쇼핑몰URL'].iloc[i]
        solution = 'request x'
        insert_data = pd.DataFrame({'url':[url],
                            'solution':[solution]})
        shop_solution = shop_solution.append(insert_data) 
shop_solution.index = range(len(shop_solution))

# %%
test.lower()
# Out:
# 'adfsfddvs fdafjioffjfji fk'

# %%
test = 'ADFSFDDVS fdafjioFFJFJI fk'

# %%
shop_solution
# Out:
#                                                    url          solution
# 0                            http://www.66girls.co.kr/            cafe24
# 1                                http://www.imvely.com            cafe24
# 2                              http://www.naning9.com/  another solution
# 3                            http://www.stylenanda.com            cafe24
# 4                             http://www.hotping.co.kr            cafe24
# 5                             http://www.sonyunara.com  another solution
# 6                            http://www.mocobling.com/          makeshop
# 7                                http://www.ggsing.com            cafe24
# 8                               http://www.thedaze.kr/            cafe24
# 9                           http://www.loveloveme.com/            cafe24
# 10                               http://www.angtoo.com            cafe24
# 11                       http://www.littleblack.co.kr/            cafe24
# 12                               http://www.11am.co.kr            cafe24
# 13                           http://www.michyeora.com/            cafe24
# 14                          http://www.miamasvin.co.kr            cafe24
# 15                          http://www.merongshop.com/            cafe24
# 16                          http://www.flymodel.co.kr/            cafe24
# 17                        http://www.maybe-baby.co.kr/            cafe24
# 18                         http://www.ribbontie.co.kr/  another solution
# 19                               http://www.ssumj.com/            cafe24
# 20                           http://www.holicholic.com            cafe24
# 21                          http://www.graychic.co.kr/            cafe24
# 22                          http://www.storynine.co.kr            cafe24
# 23                             http://www.liphop.co.kr          makeshop
# 24                          http://www.uptownholic.com          makeshop
# 25                          http://www.zemmaworld.com/            cafe24
# 26                             http://www.joamom.co.kr            cafe24
# 27                          http://www.gosister.co.kr/  another solution
# 28                            http://www.mombbe.co.kr/            cafe24
# 29                           http://www.cherrykoko.com            cafe24
# ..                                                 ...               ...
# 900                           http://www.genzshop.com/            cafe24
# 901  http://www.darkvictory.co.kr/?NaPm=ct%3Djctucc...            cafe24
# 902                           http://www.bboram.co.kr/  another solution
# 903  http://storefarm.naver.com/13month_?NaPm=ct%3D...             naver
# 904                         http://www.lovelyssam.com/            cafe24
# 905  http://www.t-nani.co.kr/?NaPm=ct%3Djctw4oj3%7C...          makeshop
# 906                        http://www.miamasvin.co.kr/            cafe24
# 907                           http://www.mahoshop.net/            cafe24
# 908                           http://www.nclass.co.kr/         request x
# 909                          http://www.10world.co.kr/            cafe24
# 910                          http://www.secretu.co.kr/            cafe24
# 911  https://swindow.naver.com/style/store/10000163...             naver
# 912                          http://barbiedress.co.kr/         request x
# 913  https://swindow.naver.com/style/store/10000163...             naver
# 914  http://www.popcornberry.com/?NaPm=ct%3Djctxr2l...            cafe24
# 915                                 http://blue9s.com/            cafe24
# 916  http://www.happyromi.co.kr/?NaPm=ct%3Djctxz5wp...          makeshop
# 917                           http://www.omeetyou.com/            cafe24
# 918                                http://show-bu.com/  another solution
# 919                           http://www.hoodya.co.kr/            cafe24
# 920                      http://www.pumpkin-coach.com/  another solution
# 921                         http://www.veracity.co.kr/          makeshop
# 922  https://swindow.naver.com/style/store/10000163...             naver
# 923                              http://10pearl.co.kr/            cafe24
# 924                           http://www.thedew.co.kr/            cafe24
# 925  http://www.be-witch.co.kr/?NaPm=ct%3Djcu1r8rw%...            cafe24
# 926                    http://www.theburninghotel.com/            cafe24
# 927                            http://www.mamabonz.com            cafe24
# 928                            www.modern-borns.co.kr/         request x
# 929                              http://www.vonze.com/  another solution
#
# [930 rows x 2 columns]

# %%
shop['solution'] = shop_solution['solution']

# %%
shop.head()
# Out:
#    분류   쇼핑몰명         회사명  대표명            연락처                   이메일  \
# 0  여성   육육걸즈        육육걸즈  박예나      1688-1360    dpskek@hanmail.net
# 1  여성    임블리      부건에프엔씨  박준성      1688-6745     help@bugunfnc.com
# 2  여성    난닝구        엔 라인  이정민      1644-8883      help@naning9.com
# 3  여성  스타일난다          난다  김소희  0502-707-8888  nanda@stylenanda.com
# 4  여성     핫핑  에스에스엘케이에이치  김여진      1588-9843   hotpingna@naver.com
#
#                       쇼핑몰URL        위치          solution
# 0  http://www.66girls.co.kr/    전북 전주시            cafe24
# 1      http://www.imvely.com   서울시 금천구            cafe24
# 2    http://www.naning9.com/   서울시 종로구  another solution
# 3  http://www.stylenanda.com   서울시 마포구            cafe24
# 4   http://www.hotping.co.kr  부산시 해운대구            cafe24

# %%
shop.to_csv('여_솔루션.csv',index=False,encoding='ANSI')

# %% [markdown]
# # 남성 쇼핑몰 solution크롤링

# %%
shop_m = pd.read_csv('남성_쇼핑몰목록.csv',engine='python')

# %%
shop_m.head()
# Out:
#    분류  순위    쇼핑몰명       회사명       대표명        쇼핑몰 연락처                   이메일  \
# 0  남성   1  슈퍼스타아이   ㈜슈퍼스타아이       김대성      1661-6874  ds_fashion@naver.com
# 1  남성   2     아보키    ㈜아보키스트       전인우      1588-8341     abokist@naver.com
# 2  남성   3      멋남  ㈜ 부건에프엔씨       박준성      1688-6747     help@bugunfnc.com
# 3  남성   4     조군샵      ㈜ 조군       조안익      1599-3120   jogunshop@naver.com
# 4  남성   5    애즈클로      애즈클로  서홍일, 서지우  070-4477-9922    hi880515@naver.com
#
#                         쇼핑몰URL                            특징,위치
# 0  http://www.superstari.co.kr   경기도 의정부시 산단로 76번길 94 504호(용현동)
# 1         http://www.aboki.net   경기도 성남시 분당구 서현동 306-3번지 3층 아보키
# 2        http://www.mutnam.com  서울특별시 금천구 디지털로 173 엘리시아 8,9,12층
# 3     http://www.jogunshop.com     경기도 부천시 원미구 중동 1086-2 6층 조군샵
# 4         http://www.asclo.com            서울특별시 성동구 청계천로 468 3층

# %%
#네이버 쇼핑몰 예외처리해야함
shop_m_solution = pd.DataFrame({'url':[],
                             'solution':[]})
for i in range(len(shop)):
    try:
        if 'naver' in shop['쇼핑몰URL'].iloc[i]:
            url = shop['쇼핑몰URL'].iloc[i]
            solution = 'naver'
            insert_data = pd.DataFrame({'url':[url],
                                        'solution':[solution]})
        else:
            url = shop['쇼핑몰URL'].iloc[i]
            req = requests.get(url)
            if req == 200 :
                soup = BeautifulSoup(req.content, 'html.parser')
            else :
                req = requests.get(url, headers = {'user-agent': ('Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko)'
                                                                                        'Chrome/71.0.3578.98 Safari/537.36')})
                soup = BeautifulSoup(req.content, 'html.parser')
            page_source = req.text
            match = re.search(r'cafe24',page_source)
                #match = re.search(r'var EC_ROOT_DOMAIN = (.+);',page_source)#보류

            if match:
                solution = 'cafe24'
            else:
                match = re.search(r'makeshop',page_source)
                if match:
                    solution = 'makeshop'
                else:
                    match = re.search(r'godohosting',page_source)
                    if match:
                        solution = 'godomall'
                    else:
                        solution = 'another solution'
                    
            insert_data = pd.DataFrame({'url':[url],
                            'solution':[solution]})
            
        shop_m_solution = shop_m_solution.append(insert_data) 
    except:
         #아예 접속이 안되는 url -> 이것도 예외처리로 봅아내면 될 듯
        url = shop['쇼핑몰URL'].iloc[i]
        solution = 'request x'
        insert_data = pd.DataFrame({'url':[url],
                            'solution':[solution]})
        shop_m_solution = shop_m_solution.append(insert_data) 
shop_m_solution.index = range(len(shop_m_solution))
# Out:
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.

# %%
shop_m_solution
# Out:
#                                  url          solution
# 0        http://www.superstari.co.kr          makeshop
# 1               http://www.aboki.net          makeshop
# 2              http://www.mutnam.com            cafe24
# 3           http://www.jogunshop.com          makeshop
# 4               http://www.asclo.com            cafe24
# 5    http://www.hun-s.com/index.html            cafe24
# 6        http://www.vivastudio.co.kr            cafe24
# 7                  http://mr-s.co.kr            cafe24
# 8          http://www.tomonari.co.kr          makeshop
# 9          http://www.modernif.co.kr            cafe24
# 10           http://www.okkane.co.kr          makeshop
# 11             http://smallman.co.kr            cafe24
# 12          http://www.leeheeeun.com            cafe24
# 13            http://www.styleman.kr            cafe24
# 14              http://www.4xr.co.kr          makeshop
# 15           http://www.flyday.co.kr            cafe24
# 16           http://www.meosidda.com            cafe24
# 17           http://www.d-answer.com          makeshop
# 18             http://www.byslim.com            cafe24
# 19                http://lakickz.com            cafe24
# 20             http://championusa.kr            cafe24
# 21               http://acover.co.kr            cafe24
# 22         http://www.boom-style.com            cafe24
# 23           http://www.redhomme.com            cafe24
# 24              http://hukubukuro.kr            cafe24
# 25            http://www.liful.co.kr          makeshop
# 26             http://www.bymono.com            cafe24
# 27              http://www.zinif.com  another solution
# 28             http://everfree.co.kr          makeshop
# 29                 http://hififnk.kr            cafe24
# ..                               ...               ...
# 188      http://www.hongdae1pro.com/            cafe24
# 189                http://jscore.kr/          makeshop
# 190           http://singer22.co.kr/  another solution
# 191     http://www.realstreet.co.kr/            cafe24
# 192             http://march5.co.kr/            cafe24
# 193        http://www.grabber.co.kr/            cafe24
# 194        http://www.taranto.co.kr/            cafe24
# 195            http://www.most1.net/            cafe24
# 196        http://www.tam-nanda.com/            cafe24
# 197         http://www.brobun.co.kr/         request x
# 198                http://6cm.co.kr/            cafe24
# 199       http://www.vintage302.com/         request x
# 200         http://www.joyhomme.com/  another solution
# 201             http://d-more.co.kr/            cafe24
# 202         http://www.lluvia.co.kr/            cafe24
# 203           http://www.alvo.co.kr/  another solution
# 204         http://www.aboutxs.co.kr            cafe24
# 205            http://noblesser.com/  another solution
# 206        http://www.themarc.co.kr/            cafe24
# 207            http://sangjis.co.kr/  another solution
# 208             http://widemode.com/         request x
# 209          http://www.gqhomme.com/          makeshop
# 210              http://clofee9.com/  another solution
# 211      http://www.danmujishop.com/            cafe24
# 212       http://www.manzgood.co.kr/            cafe24
# 213       http://www.fconcept.co.kr/         request x
# 214      http://www.thestaccato.com/  another solution
# 215              http://choixxx.com/            cafe24
# 216               http://hu-ni.co.kr         request x
# 217       http://www.xeroxero.co.kr/            cafe24
#
# [218 rows x 2 columns]

# %%
shop_m['solution'] = shop_m_solution['solution']

# %%
shop_m.head()
# Out:
#    분류  순위    쇼핑몰명       회사명       대표명            연락처                   이메일  \
# 0  남성   1  슈퍼스타아이   ㈜슈퍼스타아이       김대성      1661-6874  ds_fashion@naver.com
# 1  남성   2     아보키    ㈜아보키스트       전인우      1588-8341     abokist@naver.com
# 2  남성   3      멋남  ㈜ 부건에프엔씨       박준성      1688-6747     help@bugunfnc.com
# 3  남성   4     조군샵      ㈜ 조군       조안익      1599-3120   jogunshop@naver.com
# 4  남성   5    애즈클로      애즈클로  서홍일, 서지우  070-4477-9922    hi880515@naver.com
#
#                         쇼핑몰URL                            특징,위치  solution
# 0  http://www.superstari.co.kr   경기도 의정부시 산단로 76번길 94 504호(용현동)  makeshop
# 1         http://www.aboki.net   경기도 성남시 분당구 서현동 306-3번지 3층 아보키  makeshop
# 2        http://www.mutnam.com  서울특별시 금천구 디지털로 173 엘리시아 8,9,12층    cafe24
# 3     http://www.jogunshop.com     경기도 부천시 원미구 중동 1086-2 6층 조군샵  makeshop
# 4         http://www.asclo.com            서울특별시 성동구 청계천로 468 3층    cafe24

# %%
shop_m.to_csv('남_솔루션.csv',index=False,encoding='ANSI')

# %%
shop = pd.read_csv('여_솔루션.csv',engine = 'python')

# %%
shop_m = pd.read_csv('남_솔루션.csv',engine = 'python')

# %%
len(shop)
# Out:
# 930

# %%
len(shop[shop['solution']=='cafe24'])
# Out:
# 672

# %%
len(shop[shop['solution']=='makeshop'])
# Out:
# 137

# %%
len(shop_m)
# Out:
# 218

# %%
len(shop_m[shop_m['solution']=='cafe24'])
# Out:
# 155

# %%
len(shop_m[shop_m['solution']=='makeshop'])
# Out:
# 38

# %% [markdown]
# # 브랜디 쇼핑몰 솔루션 추출

# %%
shop_m_solution = pd.read_csv('브랜디솔루션7.csv',engine = 'python')

# %%
shop = pd.read_csv('브랜디쇼핑몰url포함.csv',engine='python')

# %%
shop.head()
# Out:
#      쇼핑몰                  연락처           카톡  \
# 0   노벰버포      연락처 : 1577-3452          NaN
# 1   삐뽕언니  연락처 : 070-8623-3086  카톡문의 : 삐뽕언니
# 2  헤이레이디  연락처 : 070-4006-0292          NaN
# 3    엘프야      연락처 : 1577-3452          NaN
# 4     사뿐   연락처 : 02-1544-2767          NaN
#
#                                                   주소  \
# 0  주소 : 04778 ) 서울 성동구 뚝섬로1길 63 (성수동1가, 영창디지털타워)영...
# 1                주소 : 48311 ) 부산 수영구 남천동 24-21층 삐뽕언니
# 2  주소 : 02577 ) 서울 동대문구 왕산로19길 61 (용두동, 용두빌딩)선농테라...
# 3  주소 : 04778 ) 서울 성동구 뚝섬로1길 63 (성수동1가, 영창디지털타워)6...
# 4  주소 : 02724 ) 서울 성북구 삼양로 69 (길음동)CJ택배 길음래미 대리점 ...
#
#                                                  url
# 0    http://novemberfour.co.kr/shopinfo/company.html
# 1                           http://bbibbongunni.com/
# 2                              http://heylady.co.kr/
# 3  https://www.fmkorea.com/index.php?document_srl...
# 4                           http://www.sappun.co.kr/

# %%
shop_m_solution = pd.DataFrame({'url':[],
                             'solution':[],
                             'name':[]})

# %%
#네이버 쇼핑몰 예외처리해야함
for i in range(2200,2226): #1755가 문제 / 
    try:
        if 'naver' in shop['url'].iloc[i]:
            url = shop['url'].iloc[i]
            name = shop['쇼핑몰'].iloc[i]
            solution = 'naver'
            insert_data = pd.DataFrame({'url':[url],
                                        'solution':[solution],
                                        'name':[name]})
        else:
            url = shop['url'].iloc[i]
            name = shop['쇼핑몰'].iloc[i]
            req = requests.get(url)
            if req == 200 :
                soup = BeautifulSoup(req.content, 'html.parser')
            else :
                req = requests.get(url, headers = {'user-agent': ('Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko)'
                                                                                        'Chrome/71.0.3578.98 Safari/537.36')})
                soup = BeautifulSoup(req.content, 'html.parser')
            page_source = req.text
            match = re.search(r'cafe24',page_source)
                #match = re.search(r'var EC_ROOT_DOMAIN = (.+);',page_source)#보류

            if match:
                solution = 'cafe24'
            else:
                match = re.search(r'makeshop',page_source)
                if match:
                    solution = 'makeshop'
                else:
                    match = re.search(r'godohosting',page_source)
                    if match:
                        solution = 'godomall'
                    else:
                        solution = 'another solution'
                    
            insert_data = pd.DataFrame({'url':[url],
                            'solution':[solution],
                            'name':[name]})
            
        shop_m_solution = shop_m_solution.append(insert_data) 
    except:
         #아예 접속이 안되는 url -> 이것도 예외처리로 봅아내면 될 듯
        url = shop['url'].iloc[i]
        name = shop['쇼핑몰'].iloc[i]
        solution = 'request x'
        insert_data = pd.DataFrame({'url':[url],
                            'solution':[solution],
                            'name':[name]})
        shop_m_solution = shop_m_solution.append(insert_data) 
shop_m_solution.index = range(len(shop_m_solution))
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-20-6926db1f74ad> in <module>()
#       3     try:
# ----> 4         if 'naver' in shop['url'].iloc[i]:
#       5             url = shop['url'].iloc[i]
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    1477             maybe_callable = com._apply_if_callable(key, self.obj)
# -> 1478             return self._getitem_axis(maybe_callable, axis=axis)
#    1479
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    2101             # validate the location
# -> 2102             self._validate_integer(key, axis)
#    2103
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _validate_integer(self, key, axis)
#    2008         if key >= l or key < -l:
# -> 2009             raise IndexError("single positional indexer is out-of-bounds")
#    2010
#
# IndexError: single positional indexer is out-of-bounds
#
# During handling of the above exception, another exception occurred:
#
# IndexError                                Traceback (most recent call last)
# <ipython-input-20-6926db1f74ad> in <module>()
#      43     except:
#      44          #아예 접속이 안되는 url -> 이것도 예외처리로 봅아내면 될 듯
# ---> 45         url = shop['url'].iloc[i]
#      46         name = shop['쇼핑몰'].iloc[i]
#      47         solution = 'request x'
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    1476
#    1477             maybe_callable = com._apply_if_callable(key, self.obj)
# -> 1478             return self._getitem_axis(maybe_callable, axis=axis)
#    1479
#    1480     def _is_scalar_access(self, key):
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    2100
#    2101             # validate the location
# -> 2102             self._validate_integer(key, axis)
#    2103
#    2104             return self._get_loc(key, axis=axis)
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _validate_integer(self, key, axis)
#    2007         l = len(ax)
#    2008         if key >= l or key < -l:
# -> 2009             raise IndexError("single positional indexer is out-of-bounds")
#    2010
#    2011     def _getitem_tuple(self, tup):
#
# IndexError: single positional indexer is out-of-bounds

# %%
shop_m_solution.index = range(len(shop_m_solution))

# %%
shop_m_solution
# Out:
#                                                     url          solution  \
# 0       http://novemberfour.co.kr/shopinfo/company.html            cafe24
# 1                              http://bbibbongunni.com/            cafe24
# 2                                 http://heylady.co.kr/            cafe24
# 3     https://www.fmkorea.com/index.php?document_srl...  another solution
# 4                              http://www.sappun.co.kr/            cafe24
# 5                           http://www.uptownholic.com/          makeshop
# 6                         http://vidfolio.kr/?author=52  another solution
# 7     /url?sa=f&rct=j&url=http://laurenhi.com/&q=&es...         request x
# 8                               http://www.hn-hn.co.kr/          makeshop
# 9                                   http://black-up.kr/            cafe24
# 10                               http://theyoons.co.kr/            cafe24
# 11     https://ko.wikipedia.org/wiki/%EC%96%B4%EC%8D%B8  another solution
# 12                                  http://oneof.co.kr/            cafe24
# 13                                     https://a-in.kr/            cafe24
# 14              https://www.brandi.co.kr/shop/moonpeach  another solution
# 15                              https://sundayup.co.kr/            cafe24
# 16      https://namu.wiki/w/%EB%B0%94%EB%8B%90%EB%9D%BC  another solution
# 17                          http://www.dailymonday.com/          makeshop
# 18                            http://www.aboutrosy.com/  another solution
# 19        https://www.brandi.co.kr/shop/jiminunnimarket  another solution
# 20    https://namu.wiki/w/%EC%86%8C%EC%9B%90(%EC%97%...  another solution
# 21        http://m.blog.naver.com/woowworld/90185360687             naver
# 22             https://www.brandi.co.kr/shop/moderntree  another solution
# 23                                  http://mix-b.co.kr/            cafe24
# 24                            http://common-unique.com/            cafe24
# 25           https://ko-kr.facebook.com/nonamesoundbar/  another solution
# 26                https://www.brandi.co.kr/shop/2ndplan  another solution
# 2214       바디네이처
# 2215         마인쥬
# 2216          빌리
# 2217  키치스KITSCHS
# 2218          영퀸
# 2219       스탠드오일
# 2220          포룸
# 2221        이에스엔
# 2222         에르비
# 2223        바람소녀
#
# [2224 rows x 3 columns]

# %%
shop_m_solution.to_csv('브랜디솔루션_최종.csv',index=False,encoding='cp949')

# %%
len(shop)
# Out:
# 2225

# %%
len(shop_m_solution)
# Out:
# 2224

# %%
shop = shop.iloc[:,:-1]

# %%
shop = shop.rename(columns = {'쇼핑몰':'name'})

# %%
shop = shop.drop(shop.index[1755])

# %%
shop.index = range(len(shop))

# %%
shop['solution'] = shop_m_solution['solution']

# %%
shop = shop.drop(shop.index[1755])
shop.index = range(len(shop))

# %%
shop
# Out:
#              쇼핑몰                  연락처                   카톡  \
# 0           노벰버포      연락처 : 1577-3452                  NaN
# 1           삐뽕언니  연락처 : 070-8623-3086          카톡문의 : 삐뽕언니
# 2          헤이레이디  연락처 : 070-4006-0292                  NaN
# 3            엘프야      연락처 : 1577-3452                  NaN
# 4             사뿐   연락처 : 02-1544-2767                  NaN
# 5          업타운홀릭  연락처 : 070-7875-9411                  NaN
# 6           앤드모어      연락처 : 1577-3452                  NaN
# 7           로렌하이      연락처 : 1661-5203          카톡문의 : 로렌하이
# 8           하늘하늘   연락처 : 02-1599-0410                  NaN
# 9            블랙업       연락처 : 15666813       카톡문의 : jsj3029
# 10           더윤즈       연락처 : 16617087                  NaN
# 11            어썸    연락처 : 01064890406     카톡문의 : withasome
# 12           원오브     연락처 : 0260320472           카톡문의 : 원오브
# 13           에이인    연락처 : 07050674534  카톡문의 : freshmoreain
# 14           문피치      연락처 : 1577-3452                  NaN
# 15          선데이업    연락처 : 07044500066                  NaN
# 16          바닐라빈      연락처 : 1577-3452                  NaN
# 17        데일리먼데이      연락처 : 1644-5426        카톡문의 : 데일리먼데이
# 18         어바웃로지    연락처 : 01076770896                  NaN
# 19        지민언니마켓  연락처 : 010-3006-1713       카톡문의 : jiminix
# 20            소원    연락처 : 01050976273                  NaN
# 21           크럼블    연락처 : 01047997229     카톡문의 : crumblekr
# 22          모던트리      연락처 : 1577-3452                  NaN
# 23           믹스비  연락처 : 070-8867-0936                  NaN
# 24         커먼유니크      연락처 : 1688-9308         카톡문의 : 커먼유니크
# 25           노네임    연락처 : 01091223493                  NaN
# 26         세컨드플랜  연락처 : 070-4042-2587                  NaN
# 27           곽자매      연락처 : 1577-3452                  NaN
# 28           본지샵      연락처 : 1644-4669           카톡문의 : 본지샵
# 29         어썸플라이   연락처 : 02-6203-9802                  NaN
# ...          ...                  ...                  ...
# 2193        아임모던      연락처 : 1577-3452                  NaN
# 2194         아쿠마    연락처 : 01047602166       카톡문의 : akumama
# 2195        모노유어      연락처 : 1577-3452                  NaN
# 2196        모노유어      연락처 : 1577-3452                  NaN
# 2197        베리제이    연락처 : 01049937881     카톡문의 : variveryj
# 2198        글로제이  연락처 : 010-4663-5142       카톡문의 : wkd9608
# 2199         라뜨라    연락처 : 01066957466     카톡문의 : pinkbell7
# 2200      모드니클로젯    연락처 : 01080245822     카톡문의 : tpdna1024
