# %%
import requests # 웹 페이지 소스를 얻기 위한 패키지(기본 내장 패키지이다.)
from bs4 import BeautifulSoup # 웹 페이지 소스를 얻기 위한 패키지, 더 간단히 얻을 수 있다는 장점이 있다고 한다.
from datetime import datetime                                # (!pip install beautifulsoup4 으로 다운받을 수 있다.)
import pandas as pd # 데이터를 처리하기 위한 가장 기본적인 패키지
import time # 사이트를 불러올 때, 작업 지연시간을 지정해주기 위한 패키지이다. (사이트가 늦게 켜지면 에러가 발생하기 때문)
import urllib.request #
from selenium.webdriver import Chrome
import json
import re     
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.keys import Keys
import datetime as dt
import numpy as np

# %% [markdown]
# # 스타일난다 상품이름

# %%
base_url = 'https://www.stylenanda.com'

# %%
big_cate=[]
for i in range(len(c_link)):
    big_cate.append(base_url + c_link[i].find('a')['href'])

# %%
all_cate = []
name_cate = []
for i in range(len(big_cate)):
    res = requests.get(big_cate[i],headers = {'user-agent': ('Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko)'
                                                                            'Chrome/71.0.3578.98 Safari/537.36')})
    soup = BeautifulSoup(res.content,'html.parser')
    a = soup.find('ul',{'class':'menuCategory'}).find_all('li')
    
    for i in range(len(a)):
        all_cate.append(base_url + a[i].find('a')['href'])
        name_cate.append(a[i].find('a').text)

# %%
all_item = pd.DataFrame({'item_name':[],
                        'category':[]})
for i in range(len(all_cate)):
    try:
        category = name_cate[i]
        res = requests.get(all_cate[i],headers = {'user-agent': ('Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko)'
                                                                                'Chrome/71.0.3578.98 Safari/537.36')})
        soup = BeautifulSoup(res.content,'html.parser') 

        leng = len(soup.find('div',{'id':'paging'}).find_all('li'))
        page_url = all_cate[i]+'&page=' + '{}'

        if leng == 5:
            for page in range(1,2):
                res = requests.get(page_url.format(page),headers = {'user-agent': ('Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko)'
                                                                                    'Chrome/71.0.3578.98 Safari/537.36')})
                soup = BeautifulSoup(res.content,'html.parser') 

                item0 = soup.find('div',{'id':'product-wrap'})
                item1 =item0.find_all('li',{'class':'item xans-record-'})

                for item in range(len(item1)):
                    item_name = item1[item].find('div',{'class':'name'}).find_all('span')[1].text

                    insert_data = pd.DataFrame({'item_name':[item_name],
                                                'category':[category]})

                    all_item = all_item.append(insert_data)
        elif leng == 6:
            for page in range(1,3):
                res = requests.get(page_url.format(page),headers = {'user-agent': ('Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko)'
                                                                                    'Chrome/71.0.3578.98 Safari/537.36')})
                soup = BeautifulSoup(res.content,'html.parser') 

                item0 = soup.find('div',{'id':'product-wrap'})
                item1 =item0.find_all('li',{'class':'item xans-record-'})

                for item in range(len(item1)):
                    item_name = item1[item].find('div',{'class':'name'}).find_all('span')[1].text

                    insert_data = pd.DataFrame({'item_name':[item_name],
                                                'category':[category]})

                    all_item = all_item.append(insert_data) 

        elif leng == 7:
            for page in range(1,4):
                res = requests.get(page_url.format(page),headers = {'user-agent': ('Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko)'
                                                                                    'Chrome/71.0.3578.98 Safari/537.36')})
                soup = BeautifulSoup(res.content,'html.parser') 

                item0 = soup.find('div',{'id':'product-wrap'})
                item1 =item0.find_all('li',{'class':'item xans-record-'})

                for item in range(len(item1)):
                    item_name = item1[item].find('div',{'class':'name'}).find_all('span')[1].text

                    insert_data = pd.DataFrame({'item_name':[item_name],
                                                'category':[category]})

                    all_item = all_item.append(insert_data)

        elif leng == 8:
            for page in range(1,5):
                res = requests.get(page_url.format(page),headers = {'user-agent': ('Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko)'
                                                                                    'Chrome/71.0.3578.98 Safari/537.36')})
                soup = BeautifulSoup(res.content,'html.parser') 

                item0 = soup.find('div',{'id':'product-wrap'})
                item1 =item0.find_all('li',{'class':'item xans-record-'})

                for item in range(len(item1)):
                    item_name = item1[item].find('div',{'class':'name'}).find_all('span')[1].text

                    insert_data = pd.DataFrame({'item_name':[item_name],
                                                'category':[category]})

                    all_item = all_item.append(insert_data)

        else:
            for page in range(1,6):
                res = requests.get(page_url.format(page),headers = {'user-agent': ('Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko)'
                                                                                    'Chrome/71.0.3578.98 Safari/537.36')})
                soup = BeautifulSoup(res.content,'html.parser') 

                item0 = soup.find('div',{'id':'product-wrap'})
                item1 =item0.find_all('li',{'class':'item xans-record-'})

                for item in range(len(item1)):
                    item_name = item1[item].find('div',{'class':'name'}).find_all('span')[1].text

                    insert_data = pd.DataFrame({'item_name':[item_name],
                                                'category':[category]})

                    all_item = all_item.append(insert_data)
    except:
        pass
    
            
            
            
all_item.index = range(len(all_item))

# %%
all_item
# Out:
#                item_name category
# 0           데이알로하 아담프릴블랑  블라우스 ()
# 1           청순꽃펀칭 태슬프릴BL  블라우스 ()
# 2         스무드터치 스트링아노락BL  블라우스 ()
# 3          꽃레이스 펀칭퍼프 숏블랑  블라우스 ()
# 4        오늘도셔링 밀키살랑크로스BL  블라우스 ()
# 5        밴딩멀티숄더 노슬리브프릴BL  블라우스 ()
# 6          하트볼륨퍼프 멀티오프블랑  블라우스 ()
# 7        섬세완벽레이스 퍼프가디건BL  블라우스 ()
# 8           시스루블룸 더블셔링블랑  블라우스 ()
# 9           펀칭플레이 셔링미니블랑  블라우스 ()
# 10        꽃자수윙프릴 핀턱노슬리브탑  블라우스 ()
# 11          원더빅프릴 노슬리브BL  블라우스 ()
# 12          꽃분클린넥 멀티퍼프블랑  블라우스 ()
# 13        오리엔탈맥시 잔꽃퍼프랩블랑  블라우스 ()
# 14         윙프릴펀칭 퍼프랩블라우스  블라우스 ()
# 15         살랑여리잔꽃 더블밴딩블랑  블라우스 ()
# 16        피크닉걸 잔잔셔링 청순BL  블라우스 ()
# 17        빅꽃칼라 체크무드 블라우스  블라우스 ()
# 18       퓨어포인트 펀칭레이스 숏블랑  블라우스 ()
# 19         워터풀나염 오픈슬리브BL  블라우스 ()
# 20       프릴빅브이 우아칼라 블라우스  블라우스 ()
# 21         퍼프셔링크롭 펀칭프릴블랑  블라우스 ()
# 22        실키프릴버튼업 도트크롭BL  블라우스 ()
# 23        방긋퍼프소매 프릴펀칭랩블랑  블라우스 ()
# 24       벌룬반소매 꼼꼼셔링 블라우스  블라우스 ()
# 25       오픈투웨이 내추럴체크린넨BL  블라우스 ()
# ...

# %%
all_item.to_csv('스타일난다상품이름.csv',encoding='cp949',index=False)

# %% [markdown]
# # 육육걸즈

# %%
base_url = 'https://66girls.co.kr/'

# %%
res = requests.get(base_url,headers = {'user-agent': ('Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko)'
                                                                                    'Chrome/71.0.3578.98 Safari/537.36')})
soup = BeautifulSoup(res.content,'html.parser')

# %%
c_link = soup.find('ul',{'class':'nav d1_wrap'}).find_all('li')[0:5]

# %%
c_link
# Out:
# [<li class="d1 xans-record-" data-param="?cate_no=81"><a href="/product/list.html?cate_no=81">아우터</a></li>,
#  <li class="d1 xans-record-" data-param="?cate_no=70"><a href="/product/list.html?cate_no=70">상의 </a></li>,
#  <li class="d1 xans-record-" data-param="?cate_no=69"><a href="/product/list.html?cate_no=69">셔츠/블라우스</a></li>,
#  <li class="d1 xans-record-" data-param="?cate_no=71"><a href="/product/list.html?cate_no=71">팬츠/데님</a></li>,
#  <li class="d1 xans-record-" data-param="?cate_no=86"><a href="/product/list.html?cate_no=86">스커트</a></li>]

# %%
big_cate=[]
for i in range(len(c_link)):
    big_cate.append(base_url + c_link[i].find('a')['href'])

# %%
big_cate
# Out:
# ['https://66girls.co.kr//product/list.html?cate_no=81',
#  'https://66girls.co.kr//product/list.html?cate_no=70',
#  'https://66girls.co.kr//product/list.html?cate_no=69',
#  'https://66girls.co.kr//product/list.html?cate_no=71',
#  'https://66girls.co.kr//product/list.html?cate_no=86']

# %%
all_cate = []
name_cate = []
for i in range(len(big_cate)):
    res = requests.get(big_cate[i],headers = {'user-agent': ('Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko)'
                                                                            'Chrome/71.0.3578.98 Safari/537.36')})
    soup = BeautifulSoup(res.content,'html.parser')
    
    a = soup.find('ul',{'class':'menuCategory'}).find_all('li')
    
    for i in range(len(a)):
        all_cate.append(base_url + a[i].find('a')['href'])
        name_cate.append(a[i].find('a').text)

# %%
all_cate
# Out:
# ['https://66girls.co.kr//product/list.html?cate_no=112',
#  'https://66girls.co.kr//product/list.html?cate_no=108',
#  'https://66girls.co.kr//product/list.html?cate_no=109',
#  'https://66girls.co.kr//product/list.html?cate_no=111',
#  'https://66girls.co.kr//product/list.html?cate_no=110',
#  'https://66girls.co.kr//product/list.html?cate_no=114',
#  'https://66girls.co.kr//product/list.html?cate_no=113',
#  'https://66girls.co.kr//product/list.html?cate_no=453',
#  'https://66girls.co.kr//product/list.html?cate_no=115',
#  'https://66girls.co.kr//product/list.html?cate_no=619',
#  'https://66girls.co.kr//product/list.html?cate_no=116',
#  'https://66girls.co.kr//product/list.html?cate_no=117',
#  'https://66girls.co.kr//product/list.html?cate_no=118',
#  'https://66girls.co.kr//product/list.html?cate_no=119',
#  'https://66girls.co.kr//product/list.html?cate_no=120',
#  'https://66girls.co.kr//product/list.html?cate_no=121',
# ...

# %%
name_cate
# Out:
# ['가디건 ()',
#  '자켓 ()',
#  '데님 재킷 ()',
#  '야상 ()',
#  '코트 ()',
#  '집업 ()',
#  '점퍼 ()',
#  '패딩 ()',
#  '베스트 ()',
#  '핸드메이드 ()',
#  '니트 ()',
#  '맨투맨 ()',
#  '후드 ()',
#  '티셔츠 ()',
#  '반팔 ()',
#  '조끼 ()',
#  '나시 ()',
#  '베이직 ()',
#  '박시핏 모음 ()',
#  '폴라티 ()',
#  '체크셔츠 ()',
#  '블라우스 ()',
#  '셔츠 ()',
#  '청바지 ()',
#  '스키니 ()',
#  '일자핏 ()',
#  '부츠컷 ()',
#  '슬랙스 ()',
#  '숏팬츠 ()',
#  '와이드 ()',
#  '멜빵/배기 ()',
#  '레깅스 ()',
#  '150-160 ()',
#  '170↑ ()',
#  '미니스커트 ()',
#  '미디스커트 ()',
#  '롱스커트 ()',
#  '플레어스커트 ()',
#  'H스커트 ()',
#  'A스커트 ()',
#  '데님스커트 ()',
#  '멜빵스커트 ()',
#  '치마바지 ()']

# %%
res = requests.get(all_cate[0],headers = {'user-agent': ('Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko)'
                                                                        'Chrome/71.0.3578.98 Safari/537.36')})
soup = BeautifulSoup(res.content,'html.parser')

# %%
len(soup.find('div',{'class':'xans-element- xans-product xans-product-normalpaging ec-base-paginate best50-hide'}).find('ol').find_all('li'))
# Out:
# 2

# %%
page_url = all_cate[0]+'&page=' + '{}'

# %%
page_url
# Out:
# 'https://66girls.co.kr//product/list.html?cate_no=112&page={}'

# %%
res = requests.get(page_url.format(1),headers = {'user-agent': ('Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko)'
                                                                    'Chrome/71.0.3578.98 Safari/537.36')})
soup = BeautifulSoup(res.content,'html.parser')

# %%
item0 = soup.find('ul',{'class':'prdList grid4'})
item1 =item0.find_all('div',{'class':'prdImg'})

# %%
len(item1)
# Out:
# 64

# %%
item1[62].find('img')['alt']
# Out:
# '비타민골지R가디건'

# %%
all_item = pd.DataFrame({'item_name':[],
                        'category':[]})
for i in range(len(all_cate)):
    try:
        category = name_cate[i]
        res = requests.get(all_cate[i],headers = {'user-agent': ('Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko)'
                                                                                'Chrome/71.0.3578.98 Safari/537.36')})
        soup = BeautifulSoup(res.content,'html.parser') 

        leng = len(soup.find('div',{'class':'xans-element- xans-product xans-product-normalpaging ec-base-paginate best50-hide'}).find('ol').find_all('li'))
        
        page_url = all_cate[i]+'&page=' + '{}'
        if leng == 1:
            for page in range(1,2):
                res = requests.get(page_url.format(page),headers = {'user-agent': ('Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko)'
                                                                                    'Chrome/71.0.3578.98 Safari/537.36')})
                soup = BeautifulSoup(res.content,'html.parser') 
            
                item0 = soup.find('ul',{'class':'prdList grid4'})
                item1 =item0.find_all('div',{'class':'prdImg'})

                for item in range(len(item1)):
                    item_name = item1[item].find('img')['alt']

                    insert_data = pd.DataFrame({'item_name':[item_name],
                                                'category':[category]})
                    
                    all_item = all_item.append(insert_data)
        elif leng == 2:
            for page in range(1,3):
                res = requests.get(page_url.format(page),headers = {'user-agent': ('Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko)'
                                                                                    'Chrome/71.0.3578.98 Safari/537.36')})
                soup = BeautifulSoup(res.content,'html.parser') 
            
                item0 = soup.find('ul',{'class':'prdList grid4'})
                item1 =item0.find_all('div',{'class':'prdImg'})

                for item in range(len(item1)):
                    item_name = item1[item].find('img')['alt']

                    insert_data = pd.DataFrame({'item_name':[item_name],
                                                'category':[category]})
                    
                    all_item = all_item.append(insert_data)
                    
        elif leng == 3:
            for page in range(1,4):
                res = requests.get(page_url.format(page),headers = {'user-agent': ('Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko)'
                                                                                    'Chrome/71.0.3578.98 Safari/537.36')})
                soup = BeautifulSoup(res.content,'html.parser') 
            
                item0 = soup.find('ul',{'class':'prdList grid4'})
                item1 =item0.find_all('div',{'class':'prdImg'})

                for item in range(len(item1)):
                    item_name = item1[item].find('img')['alt']

                    insert_data = pd.DataFrame({'item_name':[item_name],
                                                'category':[category]})  
                    
                    all_item = all_item.append(insert_data)
                    
        elif leng == 4:
            for page in range(1,5):
                res = requests.get(page_url.format(page),headers = {'user-agent': ('Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko)'
                                                                                    'Chrome/71.0.3578.98 Safari/537.36')})
                soup = BeautifulSoup(res.content,'html.parser') 
            
                item0 = soup.find('ul',{'class':'prdList grid4'})
                item1 =item0.find_all('div',{'class':'prdImg'})

                for item in range(len(item1)):
                    item_name = item1[item].find('img')['alt']

                    insert_data = pd.DataFrame({'item_name':[item_name],
                                                'category':[category]})
                    
                    all_item = all_item.append(insert_data)
                    
        else:
            for page in range(1,6):
                res = requests.get(page_url.format(page),headers = {'user-agent': ('Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko)'
                                                                                    'Chrome/71.0.3578.98 Safari/537.36')})
                soup = BeautifulSoup(res.content,'html.parser') 
            
                item0 = soup.find('ul',{'class':'prdList grid4'})
                item1 =item0.find_all('div',{'class':'prdImg'})

                for item in range(len(item1)):
                    item_name = item1[item].find('img')['alt']

                    insert_data = pd.DataFrame({'item_name':[item_name],
                                                'category':[category]})
                    
                    all_item = all_item.append(insert_data)
                    
    except:
        pass
                    
all_item.index = range(len(all_item))

# %%
all_item
# Out:
#                 item_name category
# 0                 여리브이가디건   가디건 ()
# 1                 팝콘단V가디건   가디건 ()
# 2                팝콘여리루즈CD   가디건 ()
# 3             차르르나시가디건set   가디건 ()
# 4              타이나시가디건set   가디건 ()
# 5                찰랑브이가디건T   가디건 ()
# 6                레어골지반팔CD   가디건 ()
# 7                팝콘V반팔가디건   가디건 ()
# 8                물결골지반팔CD   가디건 ()
# 9                 쿨브이반팔CD   가디건 ()
# 10               여리V루즈가디건   가디건 ()
# 11               루즈카라반팔CD   가디건 ()
# 12                 썸머단가디건   가디건 ()
# 13              라운지웨어3set   가디건 ()
# 14    배색카라반팔CD&amp;스커트set   가디건 ()
# 15             보니나시가디건set   가디건 ()
# 16               베이글단브이CD   가디건 ()
# 17               마요린넨가디건T   가디건 ()
# 18              카사리V루즈가디건   가디건 ()
# 19                로빈단가디건T   가디건 ()
# 20               레이단7부가디건   가디건 ()
# 21     골지7부가디건&amp;스커트set   가디건 ()
# 22                에이드가디건T   가디건 ()
# 23             오픈카라반팔니트cd   가디건 ()
# 24              제이스퀘어가디건T   가디건 ()
# 25             폴링나시가디건set   가디건 ()
# ...

# %%
all_item.to_csv('육육걸즈상품이름.csv',encoding='cp949',index=False)

# %% [markdown]
# # 난닝구닷컴

# %%
base_url = 'https://www.naning9.com'

# %%
res = requests.get(base_url.format(page),headers = {'user-agent': ('Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko)'
                                                                                    'Chrome/71.0.3578.98 Safari/537.36')})
soup = BeautifulSoup(res.content,'html.parser')

# %%
top_ls = soup.find('ul',{'id':'mainNavi'}).find('li',{'id':'mainTop'}).find('ul',{'class':'category'}).find_all('li')

# %%
top_ls[0].find('a')['href']
# Out:
# '/shop/list.php?cate=0S04'

# %%
all_cate = []
for i in range(len(top_ls)):
    all_cate.append(base_url+top_ls[i].find('a')['href'])

# %%
outer_ls = soup.find('ul',{'id':'mainNavi'}).find('li',{'id':'mainOuter'}).find('ul',{'class':'category'}).find_all('li')

# %%
for i in range(len(outer_ls)):
    all_cate.append(base_url+outer_ls[i].find('a')['href'])

# %%
skirt_ls = soup.find('ul',{'id':'mainNavi'}).find('li',{'id':'mainSkirtDress'}).find('ul',{'class':'category'}).find_all('li')

# %%
for i in range(len(skirt_ls)):
    all_cate.append(base_url+skirt_ls[i].find('a')['href'])

# %%
pants_ls = soup.find('ul',{'id':'mainNavi'}).find('li',{'id':'mainPants'}).find('ul',{'class':'category'}).find_all('li')

# %%
for i in range(len(pants_ls)):
    all_cate.append(base_url+pants_ls[i].find('a')['href'])

# %%
all_cate
# Out:
# ['https://www.naning9.com/shop/list.php?cate=0S04',
#  'https://www.naning9.com/shop/list.php?cate=0S01',
#  'https://www.naning9.com/shop/list.php?cate=0S02',
#  'https://www.naning9.com/shop/list.php?cate=0S05',
#  'https://www.naning9.com/shop/list.php?cate=0S06',
#  'https://www.naning9.com/shop/list.php?cate=0S07',
#  'https://www.naning9.com/shop/list.php?cate=0T0A',
#  'https://www.naning9.com/shop/list.php?cate=0T09',
#  'https://www.naning9.com/shop/list.php?cate=0T02',
#  'https://www.naning9.com/shop/list.php?cate=0T05',
#  'https://www.naning9.com/shop/list.php?cate=0T06',
#  'https://www.naning9.com/shop/list.php?cate=0T04',
#  'https://www.naning9.com/shop/list.php?cate=0T03',
#  'https://www.naning9.com/shop/list.php?cate=0T01',
#  'https://www.naning9.com/shop/list.php?cate=0U01',
#  'https://www.naning9.com/shop/list.php?cate=0U02',
#  'https://www.naning9.com/shop/list.php?cate=0U04',
#  'https://www.naning9.com/shop/list.php?cate=0U05',
# ...
