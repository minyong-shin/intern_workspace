# %%
import requests # 웹 페이지 소스를 얻기 위한 패키지(기본 내장 패키지이다.)
from bs4 import BeautifulSoup # 웹 페이지 소스를 얻기 위한 패키지, 더 간단히 얻을 수 있다는 장점이 있다고 한다.
from datetime import datetime                                # (!pip install beautifulsoup4 으로 다운받을 수 있다.)
import pandas as pd # 데이터를 처리하기 위한 가장 기본적인 패키지
import time # 사이트를 불러올 때, 작업 지연시간을 지정해주기 위한 패키지이다. (사이트가 늦게 켜지면 에러가 발생하기 때문)
import urllib.request #
from selenium.webdriver import Chrome
import json
import re

# %% [markdown]
# ---
# # lagirl 줄글로 된 사이즈표 크롤링
# ---

# %%
data = pd.DataFrame({"date" : [],
                    "image" : [],
                    "name" : [],
                    "price" : [],
                    "link" : []})

base_url = "https://www.lagirl.co.kr"

req = requests.get(base_url)
if req == 200 :
    soup = BeautifulSoup(req.content, 'html.parser')
else :
    req = requests.get(base_url, headers = {'user-agent': ('Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko)'
                                                                            'Chrome/71.0.3578.98 Safari/537.36')})
    soup = BeautifulSoup(req.content, 'html.parser')

category_list1 = soup.find('div',{'class':'xans-element- xans-layout xans-layout-category'})
#getcategory가 class와 붙어있는 것처럼 보이지만 중간에 공백으로 띄어쓰기가 되어있기 때문에
#class를 class로 사용한다
category_ls = category_list1.find_all('a')
category_url = []
category_name = []
for i in range(len(category_ls)):
    category_ls2 = base_url + category_ls[i]['href']
    category_nm = category_ls[i].text
    category_url.append(category_ls2)
    category_name.append(category_nm)
    
category_list_url = category_url[5:9]

start_url = category_list_url[0]
page_url = category_list_url[0] + '&page='+'{}'

req2 = requests.get(start_url)
if req2 == 200 :
    soup2 = BeautifulSoup(req2.content, 'html.parser')
else :
    req2 = requests.get(start_url, headers = {'user-agent': ('Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko)'
                                                                            'Chrome/71.0.3578.98 Safari/537.36')})
    soup2 = BeautifulSoup(req2.content, 'html.parser')

page1_a = soup2.find('div',{'class':'xans-element- xans-product xans-product-normalpaging ec-base-paginate'})
page2_a = page1_a.find_all('li',{'class','xans-record-'})
page1_b = page1_a.find_all('a')[-1]['href'] #가장 마지막 페이지로 가는 url
page2_b = start_url + page1_b

req3 = requests.get(page2_b)
if req3 == 200 :
    soup3 = BeautifulSoup(req3.content, 'html.parser')
else :
    req3 = requests.get(page2_b, headers = {'user-agent': ('Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko)'
                                                                            'Chrome/71.0.3578.98 Safari/537.36')})
    soup3 = BeautifulSoup(req3.content, 'html.parser')

page3_b = soup3.find('div',{'class':'xans-element- xans-product xans-product-normalpaging ec-base-paginate'})
page4_b = page3_b.find_all('li',{'class','xans-record-'})

page5 = len(page2_a) + len(page4_b)

for i in range(1,page5+1):
    req4 = requests.get(page_url.format(str(i)))
    if req4 == 200 :
        soup4 = BeautifulSoup(req4.content, 'html.parser')
    else :
        req4 = requests.get(page_url.format(str(i)), headers = {'user-agent': ('Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko)'
                                                                            'Chrome/71.0.3578.98 Safari/537.36')})
        soup4 = BeautifulSoup(req4.content, 'html.parser')
    
    product_1 = soup4.find('div',{'class':'xans-element- xans-product xans-product-listnormal ec-base-product'})
    product_2 = product_1.find_all('li',{'class':'item xans-record-'})
    
    for i in range(len(product_2)):
        name0 = product_2[i].find('p',{'class':'name'})
        name = name0.find_all('span')[2].text

        url = base_url + name0.find('a')['href']
        
        price0 = product_2[i].find('ul',{'class':'xans-element- xans-product xans-product-listitem spec'})
        price1 = price0.find_all('li',{'class':'xans-record-'})
        
        if len(price1)>2:
            price = price1[1]('span')[1].text
        else:
            price = price1[0]('span')[1].text
        
        req5 = requests.get(url)
        if req5 == 200 :
            soup5 = BeautifulSoup(req5.content, 'html.parser')
        else :
            req5 = requests.get(url, headers = {'user-agent': ('Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko)'
                                                                                'Chrome/71.0.3578.98 Safari/537.36')})
            soup5 = BeautifulSoup(req5.content, 'html.parser')

        img0 = soup5.find('div',{'class':'thumbnail'})
        img = img0.find('img')['src']

        insert_data = pd.DataFrame({"date" : datetime.today().strftime("%Y-%m-%d"),
                                    "image" : [img],
                                    "name" : [name],
                                    "price" : [price],
                                    "link" : [url]})
        
        data = data.append(insert_data)
            

data = data.drop_duplicates(subset='image', keep='last') # 중복된 부분이 있다면 가장 최근것으로 대체
data.index = range(len(data))

# %%
data
# Out:
#            date                                              image  \
# 0    2019-03-21  //www.lagirl.co.kr/web/product/medium/201903/0...
# 1    2019-03-21  //www.lagirl.co.kr/web/product/medium/201903/1...
# 2    2019-03-21  //www.lagirl.co.kr/web/product/medium/201903/5...
# 3    2019-03-21  //www.lagirl.co.kr/web/product/medium/201903/f...
# 4    2019-03-21  //www.lagirl.co.kr/web/product/medium/201903/9...
# 5    2019-03-21  //www.lagirl.co.kr/web/product/medium/201903/c...
# 6    2019-03-21  //www.lagirl.co.kr/web/product/medium/201903/6...
# 7    2019-03-21  //www.lagirl.co.kr/web/product/medium/201903/b...
# 8    2019-03-21  //www.lagirl.co.kr/web/product/medium/201903/1...
# 9    2019-03-21  //www.lagirl.co.kr/web/product/medium/201903/d...
# 10   2019-03-21  //www.lagirl.co.kr/web/product/medium/201903/c...
# 11   2019-03-21  //www.lagirl.co.kr/web/product/medium/201903/2...
# 12   2019-03-21  //www.lagirl.co.kr/web/product/medium/201903/4...
# 13   2019-03-21  //www.lagirl.co.kr/web/product/medium/201903/c...
# 14   2019-03-21  //www.lagirl.co.kr/web/product/medium/201903/4...
# 15   2019-03-21  //www.lagirl.co.kr/web/product/medium/201903/5...
# 16   2019-03-21  //www.lagirl.co.kr/web/product/medium/201903/e...
# 17   2019-03-21  //www.lagirl.co.kr/web/product/medium/201903/e...
# 18   2019-03-21  //www.lagirl.co.kr/web/product/medium/201903/9...
# 19   2019-03-21  //www.lagirl.co.kr/web/product/medium/201903/2...
# 20   2019-03-21  //www.lagirl.co.kr/web/product/medium/201903/4...
# 21   2019-03-21  //www.lagirl.co.kr/web/product/medium/201903/9...
# 22   2019-03-21  //www.lagirl.co.kr/web/product/medium/201903/e...
# 23   2019-03-21  //www.lagirl.co.kr/web/product/medium/201903/c...
# 24   2019-03-21  //www.lagirl.co.kr/web/product/medium/201903/6...
# 25   2019-03-21  //www.lagirl.co.kr/web/product/medium/201903/5...
# 26   2019-03-21  //www.lagirl.co.kr/web/product/medium/201903/3...
# 27   2019-03-21  //www.lagirl.co.kr/web/product/medium/201903/4...
# 28   2019-03-21  //www.lagirl.co.kr/web/product/medium/201903/1...
# 29   2019-03-21  //www.lagirl.co.kr/web/product/medium/201903/8...
# ..          ...                                                ...
# 256  2019-03-21  //www.lagirl.co.kr/web/product/medium/201903/3...
# 257  2019-03-21  //www.lagirl.co.kr/web/product/medium/201901/1...
# 258  2019-03-21  //www.lagirl.co.kr/web/product/medium/201903/9...
# 259  2019-03-21  //www.lagirl.co.kr/web/product/medium/201903/4...
# 260  2019-03-21  //www.lagirl.co.kr/web/product/medium/201902/b...
# 261  2019-03-21  //www.lagirl.co.kr/web/product/medium/201902/1...
# 262  2019-03-21  //www.lagirl.co.kr/web/product/medium/201902/b...
# 263  2019-03-21  //www.lagirl.co.kr/web/product/medium/201902/8...
# 264  2019-03-21  //www.lagirl.co.kr/web/product/medium/201902/2...
# 265  2019-03-21  //www.lagirl.co.kr/web/product/medium/201901/a...
# 266  2019-03-21  //www.lagirl.co.kr/web/product/medium/201810/1...
# 267  2019-03-21  //www.lagirl.co.kr/web/product/medium/201812/2...
# 268  2019-03-21  //www.lagirl.co.kr/web/product/medium/201811/8...
# 269  2019-03-21  //www.lagirl.co.kr/web/product/medium/201809/5...
# 270  2019-03-21  //www.lagirl.co.kr/web/product/medium/201901/0...
# 271  2019-03-21  //www.lagirl.co.kr/web/product/medium/201901/e...
# 272  2019-03-21  //www.lagirl.co.kr/web/product/medium/201901/b...
# 273  2019-03-21  //www.lagirl.co.kr/web/product/medium/201901/2...
# 274  2019-03-21  //www.lagirl.co.kr/web/product/medium/201901/5...
# 275  2019-03-21  //www.lagirl.co.kr/web/product/medium/201901/1...
# 276  2019-03-21  //www.lagirl.co.kr/web/product/medium/201812/2...
# 277  2019-03-21  //www.lagirl.co.kr/web/product/medium/201812/b...
# 278  2019-03-21  //www.lagirl.co.kr/web/product/medium/201812/1...
# 279  2019-03-21  //www.lagirl.co.kr/web/product/medium/201811/b...
# 280  2019-03-21  //www.lagirl.co.kr/web/product/medium/201810/1...
# 281  2019-03-21  //www.lagirl.co.kr/web/product/medium/201808/a...
# 282  2019-03-21  //www.lagirl.co.kr/web/product/medium/201807/2...
# 283  2019-03-21  //www.lagirl.co.kr/web/product/medium/201902/7...
# 284  2019-03-21  //www.lagirl.co.kr/web/product/medium/201901/2...
# 285  2019-03-21  //www.lagirl.co.kr/web/product/medium/201812/c...
#
#              name       price  \
# 0        후드아노락-jp   56,100won
# 1        라인케이프-jk   99,800won
# 2        센슈얼체크-jk   65,600won
# 3         모노대디-jk   68,400won
# 4        유닉볼륨청-jk   37,100won
# 5         퍼플데님-jk   59,000won
# 6        투웨이패드-jk  115,000won
# 7        버튼스트랩-jk   75,000won
# 8       스티트렌치-bby  109,000won
# 9         체크벌룬-jk   39,000won
# 10       베이직연청-jk   79,000won
# 11       델리롱더블-ct   75,000won
# 12        자수크롭-jk   59,000won
# 13      델리싱글체크-jk   85,000won
# 14        더블데끼-jk   72,000won
# 15      배색라인집업-jp   29,000won
# 16      언발베스-knit   25,000won
# 17       스포티프릴-jp   53,000won
# 18       화이트스탠-jk   87,000won
# 19      꽈배기니트-set   35,000won
# 20       아이스워싱-jk   68,000won
# 21        대디벨트-jk   78,000won
# 22       센치오버핏-jk  119,000won
# 23       물나염데님-jk   89,000won
# 24    패치크롭-yasang   63,000won
# 25        삥줄대디-jk   62,000won
# 26       시스루하퍼-jk   56,000won
# 27       모던체크핏-jk   89,000won
# 28      믹스블레이저-jk  115,000won
# 29    퍼프야상-yasang   74,000won
# ..            ...         ...
# 256      청배색항공-jp  139,000won
# 257       롱프렌치-ct  109,000won
# 258        롱델리-cd   34,000won
# 262  https://www.lagirl.co.kr/product/detail.html?p...
# 263  https://www.lagirl.co.kr/product/detail.html?p...
# 264  https://www.lagirl.co.kr/product/detail.html?p...
# 265  https://www.lagirl.co.kr/product/detail.html?p...
# 266  https://www.lagirl.co.kr/product/detail.html?p...
# 267  https://www.lagirl.co.kr/product/detail.html?p...
# 268  https://www.lagirl.co.kr/product/detail.html?p...
# 269  https://www.lagirl.co.kr/product/detail.html?p...
# 270  https://www.lagirl.co.kr/product/detail.html?p...
# 271  https://www.lagirl.co.kr/product/detail.html?p...
# 272  https://www.lagirl.co.kr/product/detail.html?p...
# 273  https://www.lagirl.co.kr/product/detail.html?p...
# 274  https://www.lagirl.co.kr/product/detail.html?p...
# 275  https://www.lagirl.co.kr/product/detail.html?p...
# 276  https://www.lagirl.co.kr/product/detail.html?p...
# 277  https://www.lagirl.co.kr/product/detail.html?p...
# 278  https://www.lagirl.co.kr/product/detail.html?p...
# 279  https://www.lagirl.co.kr/product/detail.html?p...
# 280  https://www.lagirl.co.kr/product/detail.html?p...
# 281  https://www.lagirl.co.kr/product/detail.html?p...
# 282  https://www.lagirl.co.kr/product/detail.html?p...
# 283  https://www.lagirl.co.kr/product/detail.html?p...
# 284  https://www.lagirl.co.kr/product/detail.html?p...
# 285  https://www.lagirl.co.kr/product/detail.html?p...
#
# [286 rows x 5 columns]

# %% [markdown]
# ---
# # 사이즈표 추출
# ---

# %%
prds = []
index = []
names = []
for i in range(len(data)) :
    prd = data['link'][i]
    ind = data.index[i]
    name = data['name'][i]
    if prd not in prds : # 중복되는 상품이 없도록 url을 수집한다.
        prds.append(prd) 
        index.append(ind) # 해당 상품에 대한 인덱스 정보가 있어야 이후에 옷 이미지와 매칭시킬 수 있으므로 인덱스 정보까지 포함한다.
        names.append(name)

# %%
df2 = pd.DataFrame({"name":[],
                    "size" : [],
                    "어깨" : [],
                    "소매" : [],
                    "암홀" : [],
                    "가슴" : [],
                   "총" : []})
for web in range(len(prds)):
    if 'set' not in names[web]:
        try:
            test_item = prds[web]

            req6 = requests.get(test_item)
            if req6 == 200 :
                soup6 = BeautifulSoup(req6.content, 'html.parser')
            else :
                req6 = requests.get(test_item, headers = {'user-agent': ('Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko)'
                                                                                            'Chrome/71.0.3578.98 Safari/537.36')})
                soup6 = BeautifulSoup(req6.content, 'html.parser')

            size0 = soup6.find('div',{'class':'cont'}).find_all('p',{'style':['text-align: center;','text-align: center; ']})
            if size0 !=[]:
                pass
            else : 
                size0=soup6.find('div',{'class':'cont'}).find_all('span',{'style':'font-family: 돋움,dotum;'})

            text0 = []
            for i in range(len(size0)):
                tt  = size0[i].text
                text0.append(tt)
            text0=set(text0)

            matchers = ['단위'] #단위와 어깨/암홀로 한 차이가 약 30상품(에러가 30개)차이가 남
            matching = [s for s in text0 if any(xs in s for xs in matchers)]

            size_t = matching[0].split()    
            size_nm = size_t[0]
            size_t2 = size_t[1:-1]

            size_col = ['size']
            size_row = [size_nm]
            for i in range(len(size_t2)):
                match = re.match(r"([가-힣]+)([0-9].+)", size_t2[i], re.I)
                if match:
                    items = match.groups()
                size_col.append(items[0])
                size_row.append(items[1])

            df_iframe = pd.DataFrame( columns = size_col)
            df = df_iframe.append(pd.Series(size_row, index=size_col), ignore_index=True)
            df["name"] = names[web]

            df2 = df2.append(df)
            #사이즈가 있는 아우터 조건문

        except:
            pass
    
df2["category"] = "Outer"
df2.index = range(len(df2))

# %%
for web in range(len(prds)):
    if 'set' not in names[web]:
        try:
            test_item = prds[web]

            req6 = requests.get(test_item)
            if req6 == 200 :
                soup6 = BeautifulSoup(req6.content, 'html.parser')
            else :
                req6 = requests.get(test_item, headers = {'user-agent': ('Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko)'
                                                                                            'Chrome/71.0.3578.98 Safari/537.36')})
                soup6 = BeautifulSoup(req6.content, 'html.parser')

            size0 = soup6.find('div',{'class':'cont'}).find_all('p',{'style':['text-align: center;','text-align: center; ']})
            if size0 !=[]:
                pass
            else : 
                size0=soup6.find('div',{'class':'cont'}).find_all('span',{'style':'font-family: 돋움,dotum;'})

            text0 = []
            for i in range(len(size0)):
                tt  = size0[i].text
                text0.append(tt)
            text0=set(text0)

            matchers = ['어깨','암홀']
            matching = [s for s in text0 if any(xs in s for xs in matchers)]
            matching

            if '단위' not in matching[0]:
                size_t = []
                for i in range(len(matching)):
                    size_t0 = matching[i].split()
                    size_t.append(size_t0)

                size_nm = []
                size_t2 = []
                for i in range(len(size_t)):
                    size_nm.append(size_t[i][0])
                    size_t2.append(size_t[i][1:])

                size_row2 = []
                size_col = ['size']
                for i in range(len(size_nm)):
                    size_row = [size_nm[i]]
                    for j in range(len(size_t2[0])):
                        match = re.match(r"([가-힣]+)([0-9].+)", size_t2[i][j], re.I)
                        if match:
                            items=match.groups()
                        size_row.append(items[1])
                        size_col.append(items[0])
                    size_row2.append(size_row)

                size_col2=size_col[0:len(size_t[0])] 

                data_f = pd.DataFrame(columns = size_col2) #data_f = pd.Dataframe()로 놓는 것이 좋음
                df_iframe = pd.DataFrame( columns = size_col2)
                for i in range(len(size_row2)):
                    df = df_iframe.append(pd.Series(size_row2[i], index=size_col2), ignore_index=True)
                    df["name"] = names[web]
                    df["category"] = 'outer'
                    data_f = data_f.append(df)
                    
                df2 = df2.append(data_f)
        except:
            pass
df2.index = range(len(df2))

# %%
# json으로 바꾸기 전 홈페이지에 넣을 용도로 none값으로 바꿔준다
df2_outer = df2.where((pd.notnull(df2)), None)
df2_outer #아우터를 뽑고 사이즈가 있는 아우터는 따로 뽑아서 append해야할 듯
# Out:
#     category          name      size    가슴     끈   뒷트임  밑단트임    벨트   벨트총  \
# 0      Outer      후드아노락-jp  (F44-66)  60.5  None  None  None  None  None
# 1      Outer      센슈얼체크-jk  (F44-66)    60  None  None  None  None  None
# 2      Outer       모노대디-jk  (F44-66)    55  None  None  None  None  None
# 3      Outer       퍼플데님-jk  (F44-66)    53  None  None  None  None  None
# 4      Outer      투웨이패드-jk  (F44-66)    54  None  None  None  None  None
# 5      Outer      버튼스트랩-jk  (F44-66)    40  None  None  None  None  None
# 6      Outer     스티트렌치-bby  (F44-66)  48.5  None  None  None  None  None
# 7      Outer       체크벌룬-jk  (F44-66)  45.5  None  None  None  None  None
# 8      Outer      베이직연청-jk  (F44-66)    55  None  None  None  None  None
# 9      Outer      델리롱더블-ct  (F44-66)    49  None  None  None  None  None
# 260       52  None  None  None  None    14    27      55  None  None
# 261       50  None  None  None  None  None    63      98  None  None
# 262       63  None  None  None  None  None  60.5      69  None  None
# 263       60  None  None  None  None  None    46    51.5  None  None
# 264       24  None  None  None  None    25    57      68  None  None
# 265       49  None  None  None  None    22    70      64  None  None
# 266       64  None  None  None  None  None  60.5      58  None  None
# 0         50  None  None  None  None  22.5  None      59  None  None
# 0         59    32  None  None  None    21  None      73  None  None
# 0       None  None  None  None  None    25    44      61  None  None
# 0       None  None  None  None  None    61    61      61  None  None
# 0       None  None  None  None  None    22  38.5      61  None  None
# 0       None  None  None  None  None    22  41.5      63  None  None
# 0       None  None  None  None  None    22    37      60  None  None
# 0       None  None  None  None  None    22    40      62  None  None
# 0       None  None  None  None  None  27.5  None      52  None  None
#
# [276 rows x 19 columns]

# %% [markdown]
# ---
# # lagirl pants
# ---

# %%
data2 = pd.DataFrame({"date" : [],
                    "image" : [],
                    "name" : [],
                    "price" : [],
                    "link" : []})

base_url = "https://www.lagirl.co.kr"

req = requests.get(base_url)
if req == 200 :
    soup = BeautifulSoup(req.content, 'html.parser')
else :
    req = requests.get(base_url, headers = {'user-agent': ('Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko)'
                                                                            'Chrome/71.0.3578.98 Safari/537.36')})
    soup = BeautifulSoup(req.content, 'html.parser')

category_list1 = soup.find('div',{'class':'xans-element- xans-layout xans-layout-category'})
#getcategory가 class와 붙어있는 것처럼 보이지만 중간에 공백으로 띄어쓰기가 되어있기 때문에
#class를 class로 사용한다
category_ls = category_list1.find_all('a')
category_url = []
category_name = []
for i in range(len(category_ls)):
    category_ls2 = base_url + category_ls[i]['href']
    category_nm = category_ls[i].text
    category_url.append(category_ls2)
    category_name.append(category_nm)
    
category_list_url = category_url[5:9]

start_url = category_list_url[2]
page_url = category_list_url[2] + '&page='+'{}'

req2 = requests.get(start_url)
if req2 == 200 :
    soup2 = BeautifulSoup(req2.content, 'html.parser')
else :
    req2 = requests.get(start_url, headers = {'user-agent': ('Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko)'
                                                                            'Chrome/71.0.3578.98 Safari/537.36')})
    soup2 = BeautifulSoup(req2.content, 'html.parser')

page1_a = soup2.find('div',{'class':'xans-element- xans-product xans-product-normalpaging ec-base-paginate'})
page2_a = page1_a.find_all('li',{'class','xans-record-'})

page1_b = page1_a.find_all('a')[-1]['href'] #가장 마지막 페이지로 가는 url
page2_b = start_url + page1_b

req3 = requests.get(page2_b)
if req3 == 200 :
    soup3 = BeautifulSoup(req3.content, 'html.parser')
else :
    req3 = requests.get(page2_b, headers = {'user-agent': ('Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko)'
                                                                            'Chrome/71.0.3578.98 Safari/537.36')})
    soup3 = BeautifulSoup(req3.content, 'html.parser')

page3_b = soup3.find('div',{'class':'xans-element- xans-product xans-product-normalpaging ec-base-paginate'})
page4_b = page3_b.find_all('li',{'class','xans-record-'})

if 1<=int(page1_b[-1])<6:
    page5 = 5 + len(page2_a) + len(page4_b)
else:
    page5 = len(page2_a) + len(page4_b)

for i in range(1,page5+1):
    req4 = requests.get(page_url.format(str(i)))
    if req4 == 200 :
        soup4 = BeautifulSoup(req4.content, 'html.parser')
    else :
        req4 = requests.get(page_url.format(str(i)), headers = {'user-agent': ('Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko)'
                                                                            'Chrome/71.0.3578.98 Safari/537.36')})
        soup4 = BeautifulSoup(req4.content, 'html.parser')
    
    product_1 = soup4.find('div',{'class':'xans-element- xans-product xans-product-listnormal ec-base-product'})
    product_2 = product_1.find_all('li',{'class':'item xans-record-'})
    
    for i in range(len(product_2)):
        name0 = product_2[i].find('p',{'class':'name'})
        name = name0.find_all('span')[2].text

        url = base_url + name0.find('a')['href']
        
        price0 = product_2[i].find('ul',{'class':'xans-element- xans-product xans-product-listitem spec'})
        price1 = price0.find_all('li',{'class':'xans-record-'})
        
        if len(price1)>2:
            price = price1[1]('span')[1].text
        else:
            price = price1[0]('span')[1].text
        
        req5 = requests.get(url)
        if req5 == 200 :
            soup5 = BeautifulSoup(req5.content, 'html.parser')
        else :
            req5 = requests.get(url, headers = {'user-agent': ('Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko)'
                                                                                'Chrome/71.0.3578.98 Safari/537.36')})
            soup5 = BeautifulSoup(req5.content, 'html.parser')

        img0 = soup5.find('div',{'class':'thumbnail'})
        img = img0.find('img')['src']

        insert_data = pd.DataFrame({"date" : datetime.today().strftime("%Y-%m-%d"),
                                    "image" : [img],
                                    "name" : [name],
                                    "price" : [price],
                                    "link" : [url]})
        
        data2 = data2.append(insert_data)
            

data2 = data2.drop_duplicates(subset='image', keep='last') # 중복된 부분이 있다면 가장 최근것으로 대체
data2.index = range(len(data2))

# %%
data2
# Out:
#            date                                              image  \
# 0    2019-03-21  //www.lagirl.co.kr/web/product/medium/201903/d...
# 1    2019-03-21  //www.lagirl.co.kr/web/product/medium/201903/a...
# 2    2019-03-21  //www.lagirl.co.kr/web/product/medium/201903/0...
# 3    2019-03-21  //www.lagirl.co.kr/web/product/medium/201903/d...
# 4    2019-03-21  //www.lagirl.co.kr/web/product/medium/201903/4...
# 5    2019-03-21  //www.lagirl.co.kr/web/product/medium/201903/2...
# 6    2019-03-21  //www.lagirl.co.kr/web/product/medium/201903/5...
# 7    2019-03-21  //www.lagirl.co.kr/web/product/medium/201903/2...
# 8    2019-03-21  //www.lagirl.co.kr/web/product/medium/201903/c...
# 9    2019-03-21  //www.lagirl.co.kr/web/product/medium/201903/c...
# 10   2019-03-21  //www.lagirl.co.kr/web/product/medium/201903/7...
# 11   2019-03-21  //www.lagirl.co.kr/web/product/medium/201903/9...
# 12   2019-03-21  //www.lagirl.co.kr/web/product/medium/201903/7...
# 13   2019-03-21  //www.lagirl.co.kr/web/product/medium/201903/c...
# 14   2019-03-21  //www.lagirl.co.kr/web/product/medium/201903/1...
# 15   2019-03-21  //www.lagirl.co.kr/web/product/medium/201903/0...
# 16   2019-03-21  //www.lagirl.co.kr/web/product/medium/201903/9...
# 17   2019-03-21  //www.lagirl.co.kr/web/product/medium/201903/b...
# 18   2019-03-21  //www.lagirl.co.kr/web/product/medium/201903/b...
# 19   2019-03-21  //www.lagirl.co.kr/web/product/medium/201903/b...
# 20   2019-03-21  //www.lagirl.co.kr/web/product/medium/201903/3...
# 21   2019-03-21  //www.lagirl.co.kr/web/product/medium/201903/7...
# 22   2019-03-21  //www.lagirl.co.kr/web/product/medium/201903/c...
# 23   2019-03-21  //www.lagirl.co.kr/web/product/medium/201903/3...
# 24   2019-03-21  //www.lagirl.co.kr/web/product/medium/201903/1...
# 25   2019-03-21  //www.lagirl.co.kr/web/product/medium/201903/5...
# 26   2019-03-21  //www.lagirl.co.kr/web/product/medium/201804/2...
# 27   2019-03-21  //www.lagirl.co.kr/web/product/medium/201903/8...
# 28   2019-03-21  //www.lagirl.co.kr/web/product/medium/201903/9...
# 29   2019-03-21  //www.lagirl.co.kr/web/product/medium/201903/2...
# ..          ...                                                ...
# 454  2019-03-21  //www.lagirl.co.kr/web/product/medium/201901/e...
# 455  2019-03-21  //www.lagirl.co.kr/web/product/medium/201901/c...
# 456  2019-03-21  //www.lagirl.co.kr/web/product/medium/201807/2...
# 457  2019-03-21  //www.lagirl.co.kr/web/product/medium/201901/9...
# 458  2019-03-21  //www.lagirl.co.kr/web/product/medium/201901/3...
# 459  2019-03-21  //www.lagirl.co.kr/web/product/medium/201901/b...
# 460  2019-03-21  //www.lagirl.co.kr/web/product/medium/201901/b...
# 461  2019-03-21  //www.lagirl.co.kr/web/product/medium/201812/6...
# 462  2019-03-21  //www.lagirl.co.kr/web/product/medium/201812/a...
# 463  2019-03-21  //www.lagirl.co.kr/web/product/medium/201812/0...
# 464  2019-03-21  //www.lagirl.co.kr/web/product/medium/201812/8...
# 465  2019-03-21  //www.lagirl.co.kr/web/product/medium/201812/f...
# 466  2019-03-21  //www.lagirl.co.kr/web/product/medium/201812/c...
# 467  2019-03-21  //www.lagirl.co.kr/web/product/medium/201812/5...
# 468  2019-03-21  //www.lagirl.co.kr/web/product/medium/201812/d...
# 469  2019-03-21  //www.lagirl.co.kr/web/product/medium/201804/2...
# 470  2019-03-21  //www.lagirl.co.kr/web/product/medium/201812/c...
# 471  2019-03-21  //www.lagirl.co.kr/web/product/medium/201812/c...
# 472  2019-03-21  //www.lagirl.co.kr/web/product/medium/201812/0...
# 473  2019-03-21  //www.lagirl.co.kr/web/product/medium/201812/e...
# 474  2019-03-21  //www.lagirl.co.kr/web/product/medium/201811/f...
# 475  2019-03-21  //www.lagirl.co.kr/web/product/medium/201811/1...
# 476  2019-03-21  //www.lagirl.co.kr/web/product/medium/201811/0...
# 477  2019-03-21  //www.lagirl.co.kr/web/product/medium/201811/8...
# 478  2019-03-21  //www.lagirl.co.kr/web/product/medium/201811/c...
# 479  2019-03-21  //www.lagirl.co.kr/web/product/medium/201810/c...
# 480  2019-03-21  //www.lagirl.co.kr/web/product/medium/201810/b...
# 481  2019-03-21  //www.lagirl.co.kr/web/product/medium/201808/7...
# 482  2019-03-21  //www.lagirl.co.kr/web/product/medium/201807/2...
# 483  2019-03-21  //www.lagirl.co.kr/web/product/medium/201807/2...
#
#                 name      price  \
# 0          부츠라인데님-pt  46,600won
# 1            비비미디-sk  33,300won
# 2          연청와이드핏-pt  43,700won
# 3           지브라밴딩-pt  45,600won
# 4           점프돌청-j/s  27,600won
# 5       하프앤데님-shorts  25,700won
# 6           플리츠밴딩-pt  37,100won
ers = {'user-agent': ('Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko)'
                                                                                            'Chrome/71.0.3578.98 Safari/537.36')})
                soup6 = BeautifulSoup(req6.content, 'html.parser')
            size0 = soup6.find('div',{'class':'cont'}).find_all('p',{'style':['text-align: center;','text-align: center; ']})
            if size0 !=[]:
                pass
            else :
                size0=soup6.find('div',{'class':'cont'}).find_all('span',{'style':'font-family: 돋움,dotum;'})
                
            text0 = []
            for i in range(len(size0)):
                tt  = size0[i].text
                text0.append(tt)
            
            text0 = set(text0)#리스트 중복제거
            
            matchers = ['힙','허벅지']

            matching = [s for s in text0 if any(xs in s for xs in matchers)]

            matching
            
            if '단위' in matching[0]: #if문사용 - 프리사이즈 - 해당 조건문 제대로 되는지 확인해야함 
            #프리사이즈가 데이터에 삽입되지가 않음...
                size_t = matching[0].split()
                size_nm = size_t[0]
                if size_t[-1] == '(단위:CM/단면)':
                    size_t2 = size_t[1:-1]
                else:
                    size_t2 = size_t[1:]

                size_col = ['size']
                size_row = [size_nm]
                for i in range(len(size_t2)):
                    match = re.match(r"([^a-zA-Z0-9]+)([0-9].+)", size_t2[i], re.I)
                    if match:
                        items = match.groups()
                    size_col.append(items[0])
                    size_row.append(items[1])

                df_iframe = pd.DataFrame( columns = size_col)
                df = df_iframe.append(pd.Series(size_row, index=size_col), ignore_index=True)
                df["name"] = names[web]

                df2 = df2.append(df)
            
            if '단위' not in matching[0]:
                size_t = []
                for i in range(len(matching)):
                    size_t0 = matching[i].split()
                    size_t.append(size_t0)

                size_nm = []
                size_t2 = []
                for i in range(len(size_t)):
                    size_nm.append(size_t[i][0])
                    size_t2.append(size_t[i][1:])

                size_row2 = []
                size_col = ['size']
                for i in range(len(size_nm)):
                    size_row = [size_nm[i]]
                    for j in range(len(size_t2[0])):
                        match = re.match(r"([가-힣]+)([0-9].+)", size_t2[i][j], re.I)
                        if match:
                            items=match.groups()
                        size_row.append(items[1])
                        size_col.append(items[0])
                    size_row2.append(size_row)

                size_col2=size_col[0:len(size_t[0])]   

                data_f = pd.DataFrame(columns = size_col2)
                df_iframe = pd.DataFrame( columns = size_col2)
                for i in range(len(size_row2)):
                    df = df_iframe.append(pd.Series(size_row2[i], index=size_col2), ignore_index=True)
                    df["name"] = names[web]
                    data_f = data_f.append(df)

                df2 = df2.append(data_f)
            
        except:
            pass

# %%
df2_json = df2.where((pd.notnull(df2)),None)

# %%
df2_json
# Out:
#               name      size    가슴   뒷트임    밑단    밑위 암홀(조절가능)    어깨  \
# 0        부츠라인데님-pt         S  None  None  23.5    25     None  None
# 0        부츠라인데님-pt         M  None  None  24.5    26     None  None
# 0          비비미디-sk  (F44-66)  None  None  None  None     None  None
# 0        연청와이드핏-pt         S  None  None    20    29     None  None
# 0        연청와이드핏-pt         M  None  None    21    30     None  None
# 0         지브라밴딩-pt  (F44-66)  None  None  33.5    37     None  None
