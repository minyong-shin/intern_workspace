# %%
import requests # 웹 페이지 소스를 얻기 위한 패키지(기본 내장 패키지이다.)
from bs4 import BeautifulSoup # 웹 페이지 소스를 얻기 위한 패키지, 더 간단히 얻을 수 있다는 장점이 있다고 한다.
from datetime import datetime                                # (!pip install beautifulsoup4 으로 다운받을 수 있다.)
import pandas as pd # 데이터를 처리하기 위한 가장 기본적인 패키지
import time # 사이트를 불러올 때, 작업 지연시간을 지정해주기 위한 패키지이다. (사이트가 늦게 켜지면 에러가 발생하기 때문)
import urllib.request #
from selenium.webdriver import Chrome
import json
import re     
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.keys import Keys
import datetime as dt

# %%
base_url = 'https://www.brandi.co.kr/shop?tag=trend'

# %%
browser = Chrome()

# %%
browser.get(base_url)

# %%
browser.find_elements_by_xpath('//*[@class = "moreBtn"]/a')[0].click()

# %%
body = browser.find_element_by_tag_name('body')#스크롤하기 위해 소스 추출

# %%
#스크롤 횟수는 11번으로 지정
num_of_pagedowns = 11
#10번 밑으로 내리는 것
while num_of_pagedowns:
    body.send_keys(Keys.PAGE_DOWN)
    time.sleep(1)
    num_of_pagedowns -= 1

# %%
browser.find_elements_by_xpath('//*[@class = "moreBtn"]/a')[0].click()

# %%
total_page = 10
num_of_pagedowns = 11

while total_page:
    total_page -=1
    while num_of_pagedowns:
        body.send_keys(Keys.PAGE_DOWN)
        time.sleep(1)
        num_of_pagedowns -= 1   
    browser.find_elements_by_xpath('//*[@class = "moreBtn"]/a')[0].click()
    time.sleep(3)
    
html = browser.page_source
html2 = BeautifulSoup(html,'html.parser')

body = html2.find('body')
app = body.find('div',{'id':'app'})

shop = app.find_all('div',{'class':'frame'})[5]
shop2 = shop.find('div',{'class':'list_store'})
shop3 = shop2.find_all('ul')

# %%
brandi  = 'https://www.brandi.co.kr'
cscenter = '/cscenter'
brandi_shop = pd.DataFrame({'cs_url':[],
                           'shop_name':[],
                           'shop_tag':[]})

for i in range(len(shop3)):
    cs_url = brandi + shop3[i].find('li',{'class':'list_store_title'}).find('a')['href'] + '/cscenter'
    shop_name = shop3[i].find('li',{'class':'list_store_title'}).text
    shop_tag = shop3[i].find('li',{'class':'list_store_tag'}).get_text()
    
    insert_data = pd.DataFrame({'cs_url':[cs_url],
                                'shop_name':[shop_name],
                               'shop_tag':[shop_tag]})
    
    brandi_shop = brandi_shop.append(insert_data)

# %%
brandi_shop.index = range(len(brandi_shop))

# %%
brandi_shop.head()
# Out:
#                                               cs_url shop_name  \
# 0  https://www.brandi.co.kr/shop/novemberfour/csc...      노벰버포
# 1  https://www.brandi.co.kr/shop/bbibbongunni/csc...      삐뽕언니
# 2     https://www.brandi.co.kr/shop/heylady/cscenter     헤이레이디
# 3       https://www.brandi.co.kr/shop/elfya/cscenter       엘프야
# 4      https://www.brandi.co.kr/shop/sappun/cscenter        사뿐
#
#            shop_tag
# 0  #20대중반#심플베이직#쇼핑몰
# 1    #20대후반#캐주얼#쇼핑몰
# 2    #20대중반#페미닌#쇼핑몰
# 3     #20대후반#페미닌#마켓
# 4  #20대중반#심플베이직#쇼핑몰

# %%
brandi_shop.to_csv('브랜디쇼핑몰정보.csv',index=False,encoding='cp949')

# %% [markdown]
# ---
# # 수집 코드
# ---

# %%
brandi_shop_info2= pd.DataFrame({'쇼핑몰':[],
                               '연락처':[],
                               '카톡':[],
                               '주소':[]})

# %%
#753부터 시작
for p in range(len(brandi_shop)):
    b_url = brandi_shop['cs_url'].iloc[p]
    name = brandi_shop['shop_name'].iloc[p]
    browser.get(b_url)
    time.sleep(3.5)
    info0 = browser.page_source
    info1 = BeautifulSoup(info0,'html.parser')
    info2 = info1.find('body')
    info3 = info2.find('div',{'class':'cs_container frame padv70'}).find('table').find('td').find('ul')
    info4 = info3.find_all('li')
    
    
    for i in range(len(info4)):
        if '연락처' in str(info4[i]):
            call = info4[i].text
        elif '카톡' in str(info4[i]):
            kakao = info4[i].text
        elif '주소' in str(info4[i]):
            mail = info4[i].text
        else:
            pass

    try:
        if call:
            pass
    except:
        call=''
    try:
        if kakao:
            pass
    except:
        kakao=''
    try:
        if mail:
            pass
    except:
        mail=''

    insert_data = pd.DataFrame({'쇼핑몰':[name],
                               '연락처':[call],
                               '카톡':[kakao],
                               '주소':[mail]})

    brandi_shop_info1 = brandi_shop_info1.append(insert_data)
    brandi_shop_info1.index = range(len(brandi_shop_info1))
    del(call)
    del(kakao)
    del(mail)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-267-7015abd8c4be> in <module>()
#       1 #753부터 시작
#       2 for p in range(2191,len(brandi_shop)+1):
# ----> 3     b_url = brandi_shop['cs_url'].iloc[p]
#       4     name = brandi_shop['shop_name'].iloc[p]
#       5     browser.get(b_url)
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    1476
#    1477             maybe_callable = com._apply_if_callable(key, self.obj)
# -> 1478             return self._getitem_axis(maybe_callable, axis=axis)
#    1479
#    1480     def _is_scalar_access(self, key):
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    2100
#    2101             # validate the location
# -> 2102             self._validate_integer(key, axis)
#    2103
#    2104             return self._get_loc(key, axis=axis)
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _validate_integer(self, key, axis)
#    2007         l = len(ax)
#    2008         if key >= l or key < -l:
# -> 2009             raise IndexError("single positional indexer is out-of-bounds")
#    2010
#    2011     def _getitem_tuple(self, tup):
#
# IndexError: single positional indexer is out-of-bounds

# %%
brandi_shop_info
# Out:
#           쇼핑몰                  연락처                     카톡  \
# 0        노벰버포      연락처 : 1577-3452
# 1        삐뽕언니  연락처 : 070-8623-3086            카톡문의 : 삐뽕언니
# 2       헤이레이디  연락처 : 070-4006-0292
# 3         엘프야      연락처 : 1577-3452
# 4          사뿐   연락처 : 02-1544-2767
# 5       업타운홀릭  연락처 : 070-7875-9411
# 6        앤드모어      연락처 : 1577-3452
# 7        로렌하이      연락처 : 1661-5203            카톡문의 : 로렌하이
# 8        하늘하늘   연락처 : 02-1599-0410
# 9         블랙업       연락처 : 15666813         카톡문의 : jsj3029
# 10        더윤즈       연락처 : 16617087
# 11         어썸    연락처 : 01064890406       카톡문의 : withasome
# 12        원오브     연락처 : 0260320472             카톡문의 : 원오브
# 13        에이인    연락처 : 07050674534    카톡문의 : freshmoreain
# 14        문피치      연락처 : 1577-3452
# 15       선데이업    연락처 : 07044500066
# 16       바닐라빈      연락처 : 1577-3452
# 17     데일리먼데이      연락처 : 1644-5426          카톡문의 : 데일리먼데이
# 18      어바웃로지    연락처 : 01076770896
# 19     지민언니마켓  연락처 : 010-3006-1713         카톡문의 : jiminix
# 20         소원    연락처 : 01050976273
# 21        크럼블    연락처 : 01047997229       카톡문의 : crumblekr
# 22       모던트리      연락처 : 1577-3452
# 23        믹스비  연락처 : 070-8867-0936
# 24      커먼유니크      연락처 : 1688-9308           카톡문의 : 커먼유니크
# 25        노네임    연락처 : 01091223493
# 26      세컨드플랜  연락처 : 070-4042-2587
# 27        곽자매      연락처 : 1577-3452
# 28        본지샵      연락처 : 1644-4669             카톡문의 : 본지샵
# 29      어썸플라이   연락처 : 02-6203-9802
주소 : 04778 ) 서울 성동구 뚝섬로1길 63 (성수동1가, 영창디지털타워)6...
# 743         주소 : 14542 ) 경기 부천시 길주로 115 (상동, 시그마타워)605
# 744                  주소 : 41921 ) 대구 중구 동산동 15-223층 라뷰
# 745  주소 : 01010 ) 서울 강북구 삼양로139길 8-12 (우이동, 태영하우스)301호
# 746      주소 : 13360 ) 경기 성남시 중원구 광명로 132 (성남동, 덕성빌딩)5층
# 747  주소 : 11944 ) 경기 구리시 벌말로 226 (수택동, 토평주공아파트)502-...
# 748        주소 : 06930 ) 서울 동작구 노량진동 283-3화동상가 APT 103호
# 749  주소 : 31021 ) 충남 천안시 서북구 성환읍 성월2길 16 (성월리, 현대한솔...
# 750  주소 : 46548 ) 부산 북구 금곡대로8번길 33 (덕천동, 아남프라자)아남프라...
# 751  주소 : 17027 ) 경기 용인시 처인구 포곡읍 둔전리 359-1신세계빌 b동 501호
#
# [752 rows x 4 columns]

# %%
cod = []
for i in range(len(brandi_shop_info)):
    if '\u30fb' in brandi_shop_info['주소'].iloc[i]:
        cod.append(i)
    else:
        pass

# %%
brandi_shop_info.to_csv('브랜디쇼핑몰.csv',index=False, encoding='cp949')

# %% [markdown]
# ---
# # 주소 추출(인접지역 영업위해)
# ---

# %%
brandi_shop_info = pd.read_csv('브랜디쇼핑몰url포함.csv',engine='python')

# %%
big = []
small= []
for i in range(len(brandi_shop_info)):
    try:
        city = brandi_shop_info['주소'].iloc[i].split()
        big.append(city[4]) 
        small.append(city[5])
    except:
        big.append('')
        small.append('')

# %%
len(small)
# Out:
# 2225

# %%
len(big)
# Out:
# 2225

# %%
brandi_shop_info['big'] = big

# %%
brandi_shop_info['small'] = small

# %%
len(brandi_shop_info[brandi_shop_info['small']=='강동구'])
# Out:
# 22

# %%
brandi_shop_info[brandi_shop_info['big']=='서울']
# Out:
#              쇼핑몰                  연락처                   카톡  \
# 0           노벰버포      연락처 : 1577-3452                  NaN
# 2          헤이레이디  연락처 : 070-4006-0292                  NaN
# 3            엘프야      연락처 : 1577-3452                  NaN
# 4             사뿐   연락처 : 02-1544-2767                  NaN
# 6           앤드모어      연락처 : 1577-3452                  NaN
# 7           로렌하이      연락처 : 1661-5203          카톡문의 : 로렌하이
# 8           하늘하늘   연락처 : 02-1599-0410                  NaN
# 9            블랙업       연락처 : 15666813       카톡문의 : jsj3029
# 12           원오브     연락처 : 0260320472           카톡문의 : 원오브
# 13           에이인    연락처 : 07050674534  카톡문의 : freshmoreain
# 14           문피치      연락처 : 1577-3452                  NaN
# 16          바닐라빈      연락처 : 1577-3452                  NaN
# 17        데일리먼데이      연락처 : 1644-5426        카톡문의 : 데일리먼데이
# 19        지민언니마켓  연락처 : 010-3006-1713       카톡문의 : jiminix
# 20            소원    연락처 : 01050976273                  NaN
# 21           크럼블    연락처 : 01047997229     카톡문의 : crumblekr
# 22          모던트리      연락처 : 1577-3452                  NaN
# 24         커먼유니크      연락처 : 1688-9308         카톡문의 : 커먼유니크
# 25           노네임    연락처 : 01091223493                  NaN
# 26         세컨드플랜  연락처 : 070-4042-2587                  NaN
# 29         어썸플라이   연락처 : 02-6203-9802                  NaN
# 33         넥스트위크   연락처 : 02-3423-2915      카톡문의 : nextweek
# 34            알콜      연락처 : 1577-3452                  NaN
# 38        925핑거스    연락처 : 01071589168                  NaN
# 39         바이너리원  연락처 : 070-4606-9336                  NaN
